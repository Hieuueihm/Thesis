# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import math
from matplotlib.image import NonUniformImage
import cv2
from itertools import zip_longest
import numpy as np
import cv2
import math
import os 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
import time
from scipy.ndimage import median_filter
import os

# %%
img_width, img_height = 128, 128

# %%
class MRELBP():
    def __init__(self, r=[2, 4, 6, 8], p = 8, w_c = 3, w_r = [3, 5, 7, 9]):
        self.r = r
        self.p = p
        self.w_c = w_c
        self.w_r = w_r
        # step :
        #   Median
        #   CI
        #   Bi-interpolation -> RI & ND
        #   Histogram

    def median_processing(self, image):
        m_3x3 = median_filter(image, size = self.w_r[0], mode='constant', cval=0)
        m_5x5 = median_filter(image, size = self.w_r[1], mode='constant', cval=0)
        m_7x7 = median_filter(image, size = self.w_r[2], mode='constant', cval=0)
        # m_9x9 = median_filter(image, size = self.w_r[3], mode='constant', cval=0)
        return m_3x3, m_5x5, m_7x7



    def mrelbp_ci(self, image, in_r):
        # r = 2 -> window_size = 5
        window_size = 2 * in_r + 1

        width, height = image.shape
        out = np.zeros((width - 2 * in_r, height - 2 * in_r), dtype=np.uint8)

        x = int(in_r /  2)
        sum_o = np.zeros((width - 2 * in_r, height - 2 * in_r))

        pixel_central =  np.zeros((width - 2 * in_r, height - 2 * in_r))
        muy_arr_central = np.zeros((width - 2 * in_r, height - 2 * in_r))

        coup = np.zeros((width - 2 * in_r, height - 2 * in_r), dtype=object)


        for i in range(0,height - 2 * in_r):
            for j in range(0,width - 2 * in_r):
                area = image[i : i + 2 * in_r +1, j :j +  2 * in_r+1]
                # print(image[i + x][j + x])
                # print(area)
                sum_o[i, j] = np.sum(area)
                # muy = np.mean(area)
                pixel_central[i, j] = image[i + 2 * x][j + 2 * x]
                scale_value = pixel_central[i, j] * ((2*in_r + 1)**2)

                # if scale_value == sum_o[i, j]:
                #     print(i, j)

                out[i,j] =  (scale_value >= sum_o[i, j])
                # coup[i, j] =  (sum_o[i, j], scale_value, out[i, j], pixel_central[i, j])
        # print(out)
        # coup_array = np.array([[f"({np.uint16(t[0])}, {np.uint16(t[1])}, {np.uint8(t[2])}, {np.uint8(t[3])}) " for t in row] for row in coup])

        # np.savetxt("out.txt", out, fmt='%d')
        # np.savetxt("pixel_central.txt", pixel_central, fmt='%d')
        # np.savetxt("muy_arr_central.txt", muy_arr_central, fmt='%d')
        # np.savetxt("diff.txt", pixel_central - muy_arr_central, fmt='%d')
        # np.savetxt("coup.txt", coup_array, fmt='%s')
        centre_hist = np.array([np.sum(out == 1), np.sum(out == 0)], dtype=np.int32)
        return out, centre_hist

    # def CI_test(self, image):
    #     m_3x3, m_5x5, m_7x7, m_9x9 = self.median_processing(image)

    #     # np.savetxt("matrix_3x3_o", m_3x3, fmt='%d')


    #     hist_r2, sum_r2 = self.mrelbp_ci(m_3x3, 2)
    #     hist_r4, sum_r4 = self.mrelbp_ci(m_3x3, 4)
    #     hist_r6, sum_r6 = self.mrelbp_ci(m_3x3, 6)
    #     hist_r8, sum_r8 = self.mrelbp_ci(m_3x3, 8)

        # print(hist_r8)


        # print(hist_r2, hist_r4, hist_r6, hist_r8)
        # np.savetxt("sum_8.txt", sum_r8, fmt='%d')

    def to_fixed_point(self, value, frac_bits=16):
        return int(value * (2 ** frac_bits))

    def convertToFixedPoint(self, value, frac_bits=16):
        integer_value = int(value)  # Convert hex to integer
        fractional_value = integer_value / (1 << frac_bits)
        return fractional_value       
    def getInterpolation(self, image, x, y, r, phi):
        lookup_table = {
            (45, 2): (0x0003E1D, 0x00057D8, 0x0002BEC, 0x0003E1D),
            (135, 2): (0x0002BEC, 0x0003E1D, 0x0003E1D, 0x00057D8),
            (225, 2): (0x0003E1D, 0x0002BEC, 0x00057D8, 0x0003E1D),
            (315, 2): (0x00057D8, 0x0003E1D, 0x0003E1D, 0x0002BEC),
            (45, 3): (0x0001B4A, 0x000C5A6, 0x00003C4, 0x0001B4A),
            (135, 3): (0x00003C4, 0x0001B4A, 0x0001B4A, 0x000C5A6),
            (225, 3): (0x0001B4A, 0x00003C4, 0x000C5A6, 0x0001B4A),
            (315, 3): (0x000C5A6, 0x0001B4A, 0x0001B4A, 0x00003C4),
            (45, 4): (0x002463, 0x000789, 0x00AFB0, 0x002463),
            (135, 4): (0x00AFB0, 0x002463, 0x002463, 0x000789),
            (225, 4): (0x002463, 0x00AFB0, 0x000789, 0x002463),
            (315, 4): (0x000789, 0x002463, 0x002463, 0x00AFB0),
            (45, 5): (0x0003FAD, 0x0003739, 0x000496B, 0x0003FAD),
            (135, 5): (0x000496B, 0x0003FAD, 0x0003FAD, 0x0003739),
            (225, 5): (0x0003FAD, 0x000496B, 0x0003739, 0x0003FAD),
            (315, 5): (0x0003739, 0x0003FAD, 0x0003FAD, 0x000496B),
            (45, 6): (0x0002F0B, 0x00092D6, 0x0000F12, 0x0002F0B),
            (135, 6): (0x0000F12, 0x0002F0B, 0x0002F0B, 0x00092D6),
            (225, 6): (0x0002F0B, 0x0000F12, 0x00092D6, 0x0002F0B),
            (315, 6): (0x00092D6, 0x0002F0B, 0x0002F0B, 0x0000F12),
            (45, 7): (0x0000C37, 0x00000A5, 0x000E6EA, 0x0000C37),
            (135, 7): (0x000E6EA, 0x0000C37, 0x0000C37, 0x00000A5),
            (225, 7): (0x0000C37, 0x000E6EA, 0x00000A5, 0x0000C37),
            (315, 7): (0x00000A5, 0x0000C37, 0x0000C37, 0x000E6EA),
            (45, 8): (0x00039B3, 0x0001E24, 0x0006E73, 0x00039B3),
            (135, 8): (0x0006E73, 0x00039B3, 0x00039B3, 0x0001E24),
            (225, 8): (0x00039B3, 0x0006E73, 0x0001E24, 0x00039B3),
            (315, 8): (0x0001E24, 0x00039B3, 0x00039B3, 0x0006E73),
        }
        r1 = lookup_table[(phi, r)][0]
        r2 = lookup_table[(phi, r)][1]
        r3 = lookup_table[(phi, r)][2]
        r4 = lookup_table[(phi, r)][3]
        x1 = int(np.floor(x))
        x2 = int(np.ceil(x))
        y1 = int(np.floor(y))
        y2 = int(np.ceil(y)) 
        r1_ = self.convertToFixedPoint(r1)
        r2_ = self.convertToFixedPoint(r2)
        r3_ = self.convertToFixedPoint(r3)
        r4_ = self.convertToFixedPoint(r4)
        # print(r1_, r2_, r3_, r4_)
        # print(r1)

        interpolated_value = (
            image[x1, y1] * r1_ +
            image[x1, y2] * r2_ +
            image[x2, y1] * r3_ +
            image[x2, y2] * r4_
        )
        return interpolated_value
        

        return interpolated_value
    def jointHistogram(self, ci, ni, rd):
        width, height = ci.shape
        out_matrix = np.zeros(200, dtype=np.uint32)
        for i in  range(0, width):
            for j in range(0, height):
                out_matrix[ci[i, j] * 100 + ni[i, j] * 10 + rd[i, j]] += 1
        return out_matrix


    def getNIDescriptor(self, NI, r, sum):
        ni_des = 0
        for index in range(1, 9):
            scale_value = NI[index] * ((2 * r + 1) ** 2)
            # print(scale_value)
            if scale_value >= sum:
                ni_des  = ni_des + 2**(index - 1)
        return ni_des

    def getRDDescriptor(self, r2, r1):
        sum = 0
        for i in range(1, 9):
            if r2[i] >= r1[i]:
                sum = sum + 2**(i - 1)

        return sum
    def ror(self, pixel):
        min_value = 255
        binary_pixel = bin(pixel)[2:].zfill(8)
        binary_pixel_int = int(binary_pixel, 2)

        for i in range(8):
            # Perform circular right shift
            result = ((binary_pixel_int >> i) | ((binary_pixel_int << (8 - i))) & 0xFF)
            if min_value > result:
                min_value = result
        return  min_value

    def checkU2(self, pixel):

        binary_pixel = bin(pixel)[2:].zfill(8)
        # print(binary_pixel)

        transitions = 0

        for i in range(8):
            current_bit = binary_pixel[i]
            next_bit = binary_pixel[(i + 1) % 8]  #

            # Check transitions
            if current_bit == '1' and next_bit == '0':
                transitions += 1
            elif current_bit == '0' and next_bit == '1':
                transitions += 1

        # Print the results
        return transitions
    def getSumPixel(self, pixel):
        sum = 0
        binary_pixel = bin(pixel)[2:].zfill(8)
        for i in range(0, 8):
            sum += int(binary_pixel[i])
        return sum


    def NI_RD_descriptor(self, image_r1, image_r2, r2):
        NI, RD = self.getNI_RD(image_r1, image_r2, r2)
        # print(NI)
        # print(RD)
        NI_out  = np.zeros(NI.shape, dtype= np.uint8)
        RD_out  = np.zeros(NI.shape, dtype= np.uint8)
        NI_width, NI_height = NI.shape
        for i in range(0, NI_height):
            for j in range(0, NI_width):
                NI_min = self.ror(np.uint8(NI[i, j]))
                NI_transitions = self.checkU2(NI_min)
                NI_des = 0
                if NI_transitions <= 2:
                    NI_des = self.getSumPixel(NI_min)
                else:
                    NI_des = 9
                NI_out[i, j] = NI_des

                RD_min  = self.ror(np.uint8(RD[i, j]))
                RD_transitions = self.checkU2(RD_min)
                RD_des = 0
                if RD_transitions <= 2:
                    RD_des = self.getSumPixel(RD_min)
                else:
                    RD_des = 9
                RD_out[i, j] = RD_des
        NI_histogram = np.histogram(NI_out,  10)[0].astype(dtype=np.int32)
        RD_histogram = np.histogram(RD_out, 10)[0].astype(dtype=np.int32)
        # NI_histogram = np.zeros(10, dtype = np.uint8)
        # RD_histogram = np.zeros(10, dtype = np.uint8)
        # for i in range(0, NI_height):
        #     for j in range(0, NI_width):
        #         NI_histogram[NI_out[i, j]] += 1
        #         RD_histogram[RD_out[i, j]] += 1
        return NI_out, RD_out, NI_histogram, RD_histogram

        return NI_out, RD_out
    def MRELBP(self, image):
        start_time = time.time()
        m_3x3, m_5x5, m_7x7 = self.median_processing(image)

        # r = 2
        ci_r2, ci_r2_count = self.mrelbp_ci(m_3x3, 2)
        ci_r4, ci_r4_count = self.mrelbp_ci(m_3x3, 4)
        ci_r6, ci_r6_count = self.mrelbp_ci(m_3x3, 6)
        ci_r8, ci_r8_count = self.mrelbp_ci(m_3x3, 8)



        NI_r2, RD_r2, NI_r2_count, RD_r2_count = self.NI_RD_descriptor(image, m_3x3, 2)
        NI_r4, RD_r4, NI_r4_count, RD_r4_count = self.NI_RD_descriptor(m_3x3, m_5x5, 4)
        NI_r6, RD_r6, NI_r6_count, RD_r6_count = self.NI_RD_descriptor(m_5x5, m_7x7, 6)
        # NI_r8, RD_r8, NI_r8_count, RD_r8_count = self.NI_RD_descriptor(m_7x7, m_9x9, 8)

        hist_r2 = self.jointHistogram(ci_r2, NI_r2, RD_r2)
        hist_r4 = self.jointHistogram(ci_r4, NI_r4, RD_r4)
        hist_r6 = self.jointHistogram(ci_r6, NI_r6, RD_r6)
        # hist_r8 = self.jointHistogram(ci_r8, NI_r8, RD_r8)

        # relbp_ni_rd_r2 = np.concatenate((NI_r2_count, RD_r2_count))
        # hist_r2_c = np.concatenate((ci_r2_count, relbp_ni_rd_r2))
        # relbp_ni_rd_r4 = np.concatenate((NI_r4_count, RD_r4_count))
        # hist_r4_c = np.concatenate((ci_r4_count, relbp_ni_rd_r4))
        # relbp_ni_rd_r6 = np.concatenate((NI_r6_count, RD_r6_count))
        # hist_r6_c = np.concatenate((ci_r6_count, relbp_ni_rd_r6))
        # relbp_ni_rd_r8 = np.concatenate((NI_r8_count, RD_r8_count))
        # hist_r8_c = np.concatenate((ci_r8_count, relbp_ni_rd_r8))

        hist_o = np.concatenate((hist_r2, hist_r4, hist_r6))
        # hist_o_1 = np.concatenate((hist_r2_c, hist_r4_c, hist_r6_c, hist_r8_c))
        end_time = time.time()

        # Calculate the total execution time
        execution_time = end_time - start_time
        print(f"Execution Time: {execution_time:.4f} seconds")

        return hist_o


        # print(hist_r2)
        # print(NI_r2)

        # print(RD_r2)




    def getInterNeighbors(self, image, r, i, j):
        if r == 1:
            S =  np.zeros(9, dtype = np.uint8)
            S[1] = image[i, j + r]
            S[2] = image[i -r , j + r]
            S[3] = image[i -r, j]
            S[4] = image[i -r, j - r]
            S[5] = image[i, j -r ]
            S[6] = image[i + r, j - r]
            S[7] = image[i + r , j]
            S[8] = image[i + r, j + r]
            return S
        angles = [45, 135, 225, 315]
        results = {}
        S =  np.zeros(9)
        S[1] = image[i, j + r]
                # S2 -> 45
        S[3] = image[i - r, j]
        S[5] = image[i, j - r]
        S[7] = image[i + r, j]
        # print(S[1], S[3], S[5], S[7])

        for angle in angles:
            theta = np.radians(angle)
            target_x = i - r * np.sin(theta)
            target_y = j + r * np.cos(theta)
                    # print(target_x, target_y)
            results[f"{angle}"] = self.getInterpolation(image, target_x, target_y, r, angle)

        S[2] = results["45"]
        S[4] = results["135"]
        S[6] = results["225"]
        S[8] = results["315"]

        return S

    def getNI_RD(self, image_r1, image_r2, r2):
        width, height = image_r2.shape
        NI = np.zeros((width - 2 * r2, height - 2 * r2))
        RD = np.zeros((width - 2 * r2, height - 2 * r2))
        r1 = r2 - 1

        # k = 0
        for i in range(r2,height - r2):
            for j in range(r2,width -r2):
                area = image_r2[i - r2  : i  + r2 + 1 , j  - r2 :j + r2 + 1]
                sum_r2_patch = np.sum(area)
                # k += 1
                r1_descriptor = self.getInterNeighbors(image_r1, r1, i, j)
                r2_descriptor = self.getInterNeighbors(image_r2, r2, i, j)

                # r1_descriptor_str = str(r1_descriptor)
                # with open("r1_inter", "a") as file:
                #     file.write(r1_descriptor_str + "\n")

                # r2_descriptor_str = str(r2_descriptor)
                # with open("r2_inter", "a") as file:
                #     file.write(r2_descriptor_str + "\n")
                #     file.write("\n")
                # for i in range(0, 9):
                #     print(r2_descriptor)
                # return
                NI[i - r2, j - r2] = self.getNIDescriptor(r2_descriptor, r2, sum_r2_patch)
                RD[i - r2, j - r2] = self.getRDDescriptor(r2_descriptor, r1_descriptor)

        return NI, RD


lbp = MRELBP()

# %%
def chiSquared(p,q):
    return np.sum((p-q)**2/(p+q+1e-6))

# %%
def make_train(root_path):
    decision_path = os.path.join(root_path, "000")
    image_path = os.path.join(root_path, "images")
    with open(decision_path + "/classes.txt", "r") as file:
        numClasses = int(file.readline())
        classes = {}
        for line in file:
            columns = line.split()
            classes[int(columns[1])] = columns[0]
    
    print("Training steps:")
    with open(decision_path + "/test.txt", "r") as train:
        numTrain = int(train.readline())
        mrelbp_hist_800 = []
        labels = []
        i = 0
        for current_line_number, line in enumerate(train):
            i = i + 1        
            labels.append(line.split()[1])
            file_name = line.split()[0]

            path_file = f'{image_path}/{file_name}'
            print(path_file)
            img = cv2.imread(path_file.rstrip(), cv2.IMREAD_GRAYSCALE)
            img_gray = cv2.resize(img, (img_width, img_height), interpolation = cv2.INTER_LANCZOS4)
            combined_hist_800 = lbp.MRELBP(img_gray)
            mrelbp_hist_800.append(combined_hist_800)
            print(i)
            if i >= numTrain:
                np.save(f'{root_path}/X_800_batch.npy', np.array(mrelbp_hist_800))
                np.save(f'{root_path}/label_batch.npy', np.array(labels))
                break

    SVM_classifier_mrelbp = make_pipeline(StandardScaler(), SVC(gamma='auto'))
    SVM_classifier_mrelbp.fit(mrelbp_hist_800,labels)
    result_labels_and_hist_800 = []
    print("testing steps:")
    with open(decision_path + "/train.txt", "r") as train:
        print(train.readline())
        # numTrain = int(train.readline())
        test_hist_800 = []
        test_labels = []
        i = 0  
        for current_line_number, line in enumerate(train):
            i = i + 1        
            test_labels.append(line.split()[1])
            file_name = line.split()[0]

            path_file = f'{image_path}/{file_name}'
            print(path_file)
            img = cv2.imread(path_file.rstrip(), cv2.IMREAD_GRAYSCALE)
                    # print(img)
            img_gray = cv2.resize(img, (img_width, img_height), interpolation = cv2.INTER_LANCZOS4)
            combined_hist_800 = lbp.MRELBP(img_gray)
            test_hist_800.append(combined_hist_800)
            result_labels_and_hist_800.append((line.split()[1], combined_hist_800))
            print(i)
            if i >= 480:
                np.save(f'{root_path}/test_800_batch.npy', np.array(result_labels_and_hist_800, dtype=object))
                break

    result_SVM_labels_mrelbp_hist = []
    
    for m in range(480):
        result_SVM_labels_mrelbp_hist.append((result_labels_and_hist_800[m][0],
                    SVM_classifier_mrelbp.predict([result_labels_and_hist_800[m][1].tolist()])))
    pred = 0
    for j in range(480):
        pred += (int(result_SVM_labels_mrelbp_hist[j][0] == result_SVM_labels_mrelbp_hist[j][1][0]))
        
    print('predictions =',pred)
    print('accuracy svm=',pred/(480)*100)

    NB_classifier_mrelbp = MultinomialNB()
    LR_classifier_mrelbp = LogisticRegression(random_state=0)
    KNN_classifier_mrelbp = KNeighborsClassifier(n_neighbors=3, weights='uniform', algorithm='auto', metric=chiSquared)

    result_NB_labels_mrelbp_hist = []
    result_LR_labels_mrelbp_hist = []
    result_KNN_labels_mrelbp_hist = []

    NB_classifier_mrelbp.fit(mrelbp_hist_800,labels)
    LR_classifier_mrelbp.fit(mrelbp_hist_800,labels)
    KNN_classifier_mrelbp.fit(mrelbp_hist_800,labels)

    for m in range(480):
        result_NB_labels_mrelbp_hist.append((result_labels_and_hist_800[m][0],
                        NB_classifier_mrelbp.predict([result_labels_and_hist_800[m][1].tolist()])))
        result_LR_labels_mrelbp_hist.append((result_labels_and_hist_800[m][0],
                        LR_classifier_mrelbp.predict([result_labels_and_hist_800[m][1].tolist()])))
        result_KNN_labels_mrelbp_hist.append((result_labels_and_hist_800[m][0],
                    KNN_classifier_mrelbp.predict([result_labels_and_hist_800[m][1].tolist()])))
        
    pred = 0
    for j in range(480):
        pred += (int(result_NB_labels_mrelbp_hist[j][0] == result_NB_labels_mrelbp_hist[j][1][0]))
        
    print('predictions =',pred)
    print('accuracy nb =',pred/(480)*100)



    pred = 0
    for j in range(480):
        pred += (int(result_LR_labels_mrelbp_hist[j][0] == result_LR_labels_mrelbp_hist[j][1][0]))
        
    print('predictions =',pred)
    print('accuracy lr =',pred/(480)*100)

    pred = 0
    for j in range(480):
        pred += (int(result_KNN_labels_mrelbp_hist[j][0] == result_KNN_labels_mrelbp_hist[j][1][0]))
        
    print('predictions =',pred)
    print('accuracy knn =',pred/(480)*100)

# %%
Dataset_dir ='D:\\Thesis\\CodeTest\\python\\Train\\Dataset'

# %%
Outex_11r= os.path.join(Dataset_dir, "Outex-TC-00011r")
Outex_11r
# Out:
# 'D:\\Thesis\\CodeTest\\python\\Train\\Dataset\\Outex-TC-00011r'

# %%
make_train(Outex_11r)
# Out:
# Training steps:
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000020.bmp
# Execution Time: 6.2252 seconds
# 1
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000021.bmp
# Execution Time: 6.1027 seconds
# 2
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000022.bmp
# Execution Time: 6.0953 seconds
# 3
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000023.bmp
# Execution Time: 5.9918 seconds
# 4
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000024.bmp
# Execution Time: 6.1302 seconds
# 5
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000025.bmp
# Execution Time: 6.2534 seconds
# 6
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000026.bmp
# Execution Time: 6.2282 seconds
# 7
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000027.bmp
# Execution Time: 6.0788 seconds
# 8
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000028.bmp
# Execution Time: 6.0878 seconds
# 9
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000029.bmp
# Execution Time: 6.1807 seconds
# 10
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000030.bmp
# Execution Time: 6.4069 seconds
# 11
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000031.bmp
# Execution Time: 6.4723 seconds
# 12
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000032.bmp
# Execution Time: 6.5396 seconds
# 13
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000033.bmp
# Execution Time: 6.7387 seconds
# 14
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000034.bmp
# Execution Time: 6.3571 seconds
# 15
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000035.bmp
# Execution Time: 6.2770 seconds
# 16
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000036.bmp
# Execution Time: 6.5877 seconds
# 17
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000037.bmp
# Execution Time: 6.6181 seconds
# 18
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000038.bmp
# Execution Time: 6.4331 seconds
# 19
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000039.bmp
# Execution Time: 6.5222 seconds
# 20
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000060.bmp
# Execution Time: 6.5328 seconds
# 21
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000061.bmp
# Execution Time: 6.4498 seconds
# 22
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000062.bmp
# Execution Time: 6.4751 seconds
# 23
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000063.bmp
# Execution Time: 6.0568 seconds
# 24
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000064.bmp
# Execution Time: 6.1752 seconds
# 25
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000065.bmp
# Execution Time: 6.0372 seconds
# 26
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000066.bmp
# Execution Time: 6.7359 seconds
# 27
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000067.bmp
# Execution Time: 7.2232 seconds
# 28
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000068.bmp
# Execution Time: 6.4677 seconds
# 29
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000069.bmp
# Execution Time: 6.6984 seconds
# 30
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000070.bmp
# Execution Time: 6.5288 seconds
# 31
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000071.bmp
# Execution Time: 6.5659 seconds
# 32
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000072.bmp
# Execution Time: 6.7160 seconds
# 33
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000073.bmp
# Execution Time: 6.4814 seconds
# 34
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000074.bmp
# Execution Time: 6.2735 seconds
# 35
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000075.bmp
# Execution Time: 6.3798 seconds
# 36
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000076.bmp
# Execution Time: 6.6777 seconds
# 37
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000077.bmp
# Execution Time: 7.4487 seconds
# 38
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000078.bmp
# Execution Time: 8.2009 seconds
# 39
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000079.bmp
# Execution Time: 8.4601 seconds
# 40
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000100.bmp
# Execution Time: 9.2921 seconds
# 41
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000101.bmp
# Execution Time: 9.1869 seconds
# 42
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000102.bmp
# Execution Time: 8.4831 seconds
# 43
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000103.bmp
# Execution Time: 8.4860 seconds
# 44
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000104.bmp
# Execution Time: 8.4559 seconds
# 45
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000105.bmp
# Execution Time: 8.3548 seconds
# 46
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000106.bmp
# Execution Time: 8.7002 seconds
# 47
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000107.bmp
# Execution Time: 9.2091 seconds
# 48
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000108.bmp
# Execution Time: 8.6997 seconds
# 49
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000109.bmp
# Execution Time: 8.4221 seconds
# 50
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000110.bmp
# Execution Time: 8.2802 seconds
# 51
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000111.bmp
# Execution Time: 7.3458 seconds
# 52
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000112.bmp
# Execution Time: 7.2138 seconds
# 53
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000113.bmp
# Execution Time: 7.4233 seconds
# 54
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000114.bmp
# Execution Time: 7.2270 seconds
# 55
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000115.bmp
# Execution Time: 7.2040 seconds
# 56
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000116.bmp
# Execution Time: 6.6746 seconds
# 57
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000117.bmp
# Execution Time: 8.0781 seconds
# 58
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000118.bmp
# Execution Time: 8.1675 seconds
# 59
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000119.bmp
# Execution Time: 8.1501 seconds
# 60
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000140.bmp
# Execution Time: 6.5830 seconds
# 61
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000141.bmp
# Execution Time: 6.4145 seconds
# 62
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000142.bmp
# Execution Time: 6.3498 seconds
# 63
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000143.bmp
# Execution Time: 6.4573 seconds
# 64
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000144.bmp
# Execution Time: 6.6644 seconds
# 65
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000145.bmp
# Execution Time: 7.0237 seconds
# 66
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000146.bmp
# Execution Time: 6.8189 seconds
# 67
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000147.bmp
# Execution Time: 7.8946 seconds
# 68
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000148.bmp
# Execution Time: 7.3726 seconds
# 69
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000149.bmp
# Execution Time: 6.7416 seconds
# 70
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000150.bmp
# Execution Time: 6.5028 seconds
# 71
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000151.bmp
# Execution Time: 6.5408 seconds
# 72
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000152.bmp
# Execution Time: 6.7230 seconds
# 73
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000153.bmp
# Execution Time: 7.1764 seconds
# 74
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000154.bmp
# Execution Time: 6.4340 seconds
# 75
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000155.bmp
# Execution Time: 6.2968 seconds
# 76
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000156.bmp
# Execution Time: 6.1508 seconds
# 77
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000157.bmp
# Execution Time: 6.2879 seconds
# 78
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000158.bmp
# Execution Time: 6.3831 seconds
# 79
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000159.bmp
# Execution Time: 6.5925 seconds
# 80
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000180.bmp
# Execution Time: 7.3519 seconds
# 81
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000181.bmp
# Execution Time: 7.1231 seconds
# 82
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000182.bmp
# Execution Time: 7.2454 seconds
# 83
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000183.bmp
# Execution Time: 7.2882 seconds
# 84
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000184.bmp
# Execution Time: 7.2463 seconds
# 85
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000185.bmp
# Execution Time: 6.8071 seconds
# 86
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000186.bmp
# Execution Time: 7.4559 seconds
# 87
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000187.bmp
# Execution Time: 6.8009 seconds
# 88
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000188.bmp
# Execution Time: 6.8392 seconds
# 89
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000189.bmp
# Execution Time: 6.3651 seconds
# 90
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000190.bmp
# Execution Time: 6.0640 seconds
# 91
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000191.bmp
# Execution Time: 6.0949 seconds
# 92
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000192.bmp
# Execution Time: 6.1391 seconds
# 93
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000193.bmp
# Execution Time: 6.6892 seconds
# 94
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000194.bmp
# Execution Time: 6.1557 seconds
# 95
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000195.bmp
# Execution Time: 6.0031 seconds
# 96
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000196.bmp
# Execution Time: 6.0306 seconds
# 97
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000197.bmp
# Execution Time: 6.1051 seconds
# 98
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000198.bmp
# Execution Time: 6.5071 seconds
# 99
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000199.bmp
# Execution Time: 6.8786 seconds
# 100
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000220.bmp
# Execution Time: 7.8736 seconds
# 101
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000221.bmp
# Execution Time: 6.4238 seconds
# 102
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000222.bmp
# Execution Time: 6.3508 seconds
# 103
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000223.bmp
# Execution Time: 6.3442 seconds
# 104
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000224.bmp
# Execution Time: 6.7677 seconds
# 105
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000225.bmp
# Execution Time: 6.4890 seconds
# 106
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000226.bmp
# Execution Time: 6.4697 seconds
# 107
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000227.bmp
# Execution Time: 6.5681 seconds
# 108
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000228.bmp
# Execution Time: 6.2768 seconds
# 109
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000229.bmp
# Execution Time: 6.4251 seconds
# 110
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000230.bmp
# Execution Time: 6.2977 seconds
# 111
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000231.bmp
# Execution Time: 6.3684 seconds
# 112
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000232.bmp
# Execution Time: 6.2761 seconds
# 113
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000233.bmp
# Execution Time: 6.3198 seconds
# 114
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000234.bmp
# Execution Time: 6.5080 seconds
# 115
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000235.bmp
# Execution Time: 6.1810 seconds
# 116
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000236.bmp
# Execution Time: 6.0951 seconds
# 117
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000237.bmp
# Execution Time: 6.1185 seconds
# 118
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000238.bmp
# Execution Time: 7.4097 seconds
# 119
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000239.bmp
# Execution Time: 8.0138 seconds
# 120
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000260.bmp
# Execution Time: 7.7397 seconds
# 121
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000261.bmp
# Execution Time: 8.0999 seconds
# 122
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000262.bmp
# Execution Time: 6.9187 seconds
# 123
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000263.bmp
# Execution Time: 6.7364 seconds
# 124
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000264.bmp
# Execution Time: 6.6987 seconds
# 125
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000265.bmp
# Execution Time: 6.4940 seconds
# 126
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000266.bmp
# Execution Time: 7.1689 seconds
# 127
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000267.bmp
# Execution Time: 6.3032 seconds
# 128
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000268.bmp
# Execution Time: 6.3948 seconds
# 129
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000269.bmp
# Execution Time: 6.4122 seconds
# 130
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000270.bmp
# Execution Time: 7.7086 seconds
# 131
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000271.bmp
# Execution Time: 7.3772 seconds
# 132
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000272.bmp
# Execution Time: 7.3655 seconds
# 133
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000273.bmp
# Execution Time: 6.9573 seconds
# 134
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000274.bmp
# Execution Time: 7.7643 seconds
# 135
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000275.bmp
# Execution Time: 8.2138 seconds
# 136
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000276.bmp
# Execution Time: 8.3636 seconds
# 137
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000277.bmp
# Execution Time: 8.6819 seconds
# 138
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000278.bmp
# Execution Time: 9.1219 seconds
# 139
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000279.bmp
# Execution Time: 8.1472 seconds
# 140
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000300.bmp
# Execution Time: 8.8981 seconds
# 141
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000301.bmp
# Execution Time: 8.9513 seconds
# 142
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000302.bmp
# Execution Time: 8.5235 seconds
# 143
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000303.bmp
# Execution Time: 8.5403 seconds
# 144
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000304.bmp
# Execution Time: 7.5054 seconds
# 145
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000305.bmp
# Execution Time: 7.2364 seconds
# 146
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000306.bmp
# Execution Time: 7.1052 seconds
# 147
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000307.bmp
# Execution Time: 7.1139 seconds
# 148
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000308.bmp
# Execution Time: 7.1001 seconds
# 149
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000309.bmp
# Execution Time: 7.0234 seconds
# 150
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000310.bmp
# Execution Time: 7.8318 seconds
# 151
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000311.bmp
# Execution Time: 9.4026 seconds
# 152
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000312.bmp
# Execution Time: 6.9889 seconds
# 153
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000313.bmp
# Execution Time: 6.8131 seconds
# 154
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000314.bmp
# Execution Time: 6.8995 seconds
# 155
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000315.bmp
# Execution Time: 6.7039 seconds
# 156
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000316.bmp
# Execution Time: 6.5534 seconds
# 157
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000317.bmp
# Execution Time: 6.4571 seconds
# 158
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000318.bmp
# Execution Time: 6.7169 seconds
# 159
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000319.bmp
# Execution Time: 6.4186 seconds
# 160
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000340.bmp
# Execution Time: 6.0801 seconds
# 161
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000341.bmp
# Execution Time: 6.3385 seconds
# 162
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000342.bmp
# Execution Time: 6.3621 seconds
# 163
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000343.bmp
# Execution Time: 8.1661 seconds
# 164
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000344.bmp
# Execution Time: 7.5121 seconds
# 165
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000345.bmp
# Execution Time: 6.0440 seconds
# 166
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000346.bmp
# Execution Time: 6.4091 seconds
# 167
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000347.bmp
# Execution Time: 7.6690 seconds
# 168
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000348.bmp
# Execution Time: 6.5759 seconds
# 169
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000349.bmp
# Execution Time: 6.4011 seconds
# 170
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000350.bmp
# Execution Time: 5.9940 seconds
# 171
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000351.bmp
# Execution Time: 6.3257 seconds
# 172
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000352.bmp
# Execution Time: 7.2184 seconds
# 173
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000353.bmp
# Execution Time: 6.7766 seconds
# 174
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000354.bmp
# Execution Time: 6.7641 seconds
# 175
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000355.bmp
# Execution Time: 6.5724 seconds
# 176
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000356.bmp
# Execution Time: 6.4753 seconds
# 177
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000357.bmp
# Execution Time: 6.9424 seconds
# 178
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000358.bmp
# Execution Time: 6.3798 seconds
# 179
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000359.bmp
# Execution Time: 6.3791 seconds
# 180
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000380.bmp
# Execution Time: 6.3171 seconds
# 181
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000381.bmp
# Execution Time: 6.3908 seconds
# 182
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000382.bmp
# Execution Time: 7.7884 seconds
# 183
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000383.bmp
# Execution Time: 7.0536 seconds
# 184
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000384.bmp
# Execution Time: 7.2607 seconds
# 185
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000385.bmp
# Execution Time: 7.4156 seconds
# 186
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000386.bmp
# Execution Time: 7.9981 seconds
# 187
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000387.bmp
# Execution Time: 8.0479 seconds
# 188
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000388.bmp
# Execution Time: 8.5737 seconds
# 189
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000389.bmp
# Execution Time: 8.4449 seconds
# 190
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000390.bmp
# Execution Time: 8.3642 seconds
# 191
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000391.bmp
# Execution Time: 8.5897 seconds
# 192
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000392.bmp
# Execution Time: 8.3445 seconds
# 193
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000393.bmp
# Execution Time: 8.3365 seconds
# 194
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000394.bmp
# Execution Time: 8.2581 seconds
# 195
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000395.bmp
# Execution Time: 8.2076 seconds
# 196
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000396.bmp
# Execution Time: 7.4979 seconds
# 197
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000397.bmp
# Execution Time: 7.1441 seconds
# 198
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000398.bmp
# Execution Time: 7.3451 seconds
# 199
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000399.bmp
# Execution Time: 7.1324 seconds
# 200
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000420.bmp
# Execution Time: 6.9679 seconds
# 201
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000421.bmp
# Execution Time: 7.1835 seconds
# 202
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000422.bmp
# Execution Time: 6.7837 seconds
# 203
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000423.bmp
# Execution Time: 7.0285 seconds
# 204
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000424.bmp
# Execution Time: 7.9278 seconds
# 205
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000425.bmp
# Execution Time: 8.0019 seconds
# 206
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000426.bmp
# Execution Time: 8.1524 seconds
# 207
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000427.bmp
# Execution Time: 6.6910 seconds
# 208
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000428.bmp
# Execution Time: 6.8859 seconds
# 209
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000429.bmp
# Execution Time: 7.1268 seconds
# 210
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000430.bmp
# Execution Time: 6.5658 seconds
# 211
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000431.bmp
# Execution Time: 6.3812 seconds
# 212
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000432.bmp
# Execution Time: 8.3130 seconds
# 213
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000433.bmp
# Execution Time: 7.0227 seconds
# 214
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000434.bmp
# Execution Time: 6.9040 seconds
# 215
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000435.bmp
# Execution Time: 6.6751 seconds
# 216
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000436.bmp
# Execution Time: 6.5907 seconds
# 217
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000437.bmp
# Execution Time: 6.9444 seconds
# 218
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000438.bmp
# Execution Time: 6.8276 seconds
# 219
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000439.bmp
# Execution Time: 6.8316 seconds
# 220
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000460.bmp
# Execution Time: 6.8314 seconds
# 221
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000461.bmp
# Execution Time: 6.6863 seconds
# 222
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000462.bmp
# Execution Time: 6.4394 seconds
# 223
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000463.bmp
# Execution Time: 6.6604 seconds
# 224
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000464.bmp
# Execution Time: 6.1798 seconds
# 225
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000465.bmp
# Execution Time: 6.0848 seconds
# 226
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000466.bmp
# Execution Time: 6.3188 seconds
# 227
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000467.bmp
# Execution Time: 7.5637 seconds
# 228
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000468.bmp
# Execution Time: 6.4792 seconds
# 229
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000469.bmp
# Execution Time: 6.2269 seconds
# 230
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000470.bmp
# Execution Time: 6.3661 seconds
# 231
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000471.bmp
# Execution Time: 6.0288 seconds
# 232
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000472.bmp
# Execution Time: 6.0558 seconds
# 233
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000473.bmp
# Execution Time: 6.1319 seconds
# 234
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000474.bmp
# Execution Time: 6.2919 seconds
# 235
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000475.bmp
# Execution Time: 6.7789 seconds
# 236
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000476.bmp
# Execution Time: 6.6633 seconds
# 237
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000477.bmp
# Execution Time: 6.9246 seconds
# 238
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000478.bmp
# Execution Time: 7.0206 seconds
# 239
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000479.bmp
# Execution Time: 6.3595 seconds
# 240
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000500.bmp
# Execution Time: 6.6000 seconds
# 241
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000501.bmp
# Execution Time: 6.4602 seconds
# 242
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000502.bmp
# Execution Time: 6.4572 seconds
# 243
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000503.bmp
# Execution Time: 6.9452 seconds
# 244
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000504.bmp
# Execution Time: 6.3822 seconds
# 245
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000505.bmp
# Execution Time: 6.3650 seconds
# 246
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000506.bmp
# Execution Time: 6.2938 seconds
# 247
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000507.bmp
# Execution Time: 6.8881 seconds
# 248
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000508.bmp
# Execution Time: 7.3105 seconds
# 249
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000509.bmp
# Execution Time: 7.1339 seconds
# 250
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000510.bmp
# Execution Time: 7.1962 seconds
# 251
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000511.bmp
# Execution Time: 7.9383 seconds
# 252
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000512.bmp
# Execution Time: 8.4393 seconds
# 253
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000513.bmp
# Execution Time: 8.1724 seconds
# 254
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000514.bmp
# Execution Time: 8.2563 seconds
# 255
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000515.bmp
# Execution Time: 8.2670 seconds
# 256
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000516.bmp
# Execution Time: 8.3507 seconds
# 257
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000517.bmp
# Execution Time: 8.2268 seconds
# 258
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000518.bmp
# Execution Time: 8.3422 seconds
# 259
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000519.bmp
# Execution Time: 8.4095 seconds
# 260
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000540.bmp
# Execution Time: 8.2947 seconds
# 261
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000541.bmp
# Execution Time: 7.9170 seconds
# 262
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000542.bmp
# Execution Time: 7.1269 seconds
# 263
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000543.bmp
# Execution Time: 7.0393 seconds
# 264
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000544.bmp
# Execution Time: 7.2569 seconds
# 265
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000545.bmp
# Execution Time: 7.0606 seconds
# 266
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000546.bmp
# Execution Time: 6.9317 seconds
# 267
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000547.bmp
# Execution Time: 7.0261 seconds
# 268
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000548.bmp
# Execution Time: 7.1977 seconds
# 269
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000549.bmp
# Execution Time: 8.1636 seconds
# 270
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000550.bmp
# Execution Time: 6.9851 seconds
# 271
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000551.bmp
# Execution Time: 6.5219 seconds
# 272
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000552.bmp
# Execution Time: 6.5948 seconds
# 273
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000553.bmp
# Execution Time: 6.6635 seconds
# 274
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000554.bmp
# Execution Time: 6.5100 seconds
# 275
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000555.bmp
# Execution Time: 6.6632 seconds
# 276
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000556.bmp
# Execution Time: 6.7861 seconds
# 277
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000557.bmp
# Execution Time: 6.4614 seconds
# 278
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000558.bmp
# Execution Time: 6.1401 seconds
# 279
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000559.bmp
# Execution Time: 6.0037 seconds
# 280
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000580.bmp
# Execution Time: 5.9588 seconds
# 281
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000581.bmp
# Execution Time: 5.9498 seconds
# 282
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000582.bmp
# Execution Time: 5.9476 seconds
# 283
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000583.bmp
# Execution Time: 6.1053 seconds
# 284
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000584.bmp
# Execution Time: 5.9571 seconds
# 285
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000585.bmp
# Execution Time: 5.9101 seconds
# 286
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000586.bmp
# Execution Time: 5.9320 seconds
# 287
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000587.bmp
# Execution Time: 5.9015 seconds
# 288
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000588.bmp
# Execution Time: 5.8860 seconds
# 289
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000589.bmp
# Execution Time: 5.9213 seconds
# 290
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000590.bmp
# Execution Time: 6.0203 seconds
# 291
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000591.bmp
# Execution Time: 6.2131 seconds
# 292
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000592.bmp
# Execution Time: 7.6829 seconds
# 293
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000593.bmp
# Execution Time: 6.2441 seconds
# 294
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000594.bmp
# Execution Time: 9.2179 seconds
# 295
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000595.bmp
# Execution Time: 6.5713 seconds
# 296
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000596.bmp
# Execution Time: 6.8771 seconds
# 297
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000597.bmp
# Execution Time: 7.1452 seconds
# 298
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000598.bmp
# Execution Time: 6.9040 seconds
# 299
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000599.bmp
# Execution Time: 7.4526 seconds
# 300
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000620.bmp
# Execution Time: 6.3263 seconds
# 301
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000621.bmp
# Execution Time: 6.8837 seconds
# 302
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000622.bmp
# Execution Time: 6.1146 seconds
# 303
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000623.bmp
# Execution Time: 5.9358 seconds
# 304
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000624.bmp
# Execution Time: 6.0260 seconds
# 305
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000625.bmp
# Execution Time: 5.9660 seconds
# 306
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000626.bmp
# Execution Time: 5.9220 seconds
# 307
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000627.bmp
# Execution Time: 5.9815 seconds
# 308
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000628.bmp
# Execution Time: 5.9356 seconds
# 309
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000629.bmp
# Execution Time: 5.9740 seconds
# 310
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000630.bmp
# Execution Time: 5.9208 seconds
# 311
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000631.bmp
# Execution Time: 5.9353 seconds
# 312
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000632.bmp
# Execution Time: 5.9286 seconds
# 313
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000633.bmp
# Execution Time: 5.9346 seconds
# 314
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000634.bmp
# Execution Time: 6.0121 seconds
# 315
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000635.bmp
# Execution Time: 5.9369 seconds
# 316
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000636.bmp
# Execution Time: 5.9552 seconds
# 317
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000637.bmp
# Execution Time: 5.9173 seconds
# 318
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000638.bmp
# Execution Time: 5.9291 seconds
# 319
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000639.bmp
# Execution Time: 6.0007 seconds
# 320
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000660.bmp
# Execution Time: 5.9837 seconds
# 321
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000661.bmp
# Execution Time: 5.9885 seconds
# 322
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000662.bmp
# Execution Time: 5.9480 seconds
# 323
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000663.bmp
# Execution Time: 6.2330 seconds
# 324
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000664.bmp
# Execution Time: 6.1278 seconds
# 325
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000665.bmp
# Execution Time: 6.0422 seconds
# 326
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000666.bmp
# Execution Time: 6.0371 seconds
# 327
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000667.bmp
# Execution Time: 5.9400 seconds
# 328
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000668.bmp
# Execution Time: 5.9148 seconds
# 329
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000669.bmp
# Execution Time: 5.9073 seconds
# 330
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000670.bmp
# Execution Time: 5.9265 seconds
# 331
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000671.bmp
# Execution Time: 5.9388 seconds
# 332
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000672.bmp
# Execution Time: 5.9635 seconds
# 333
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000673.bmp
# Execution Time: 5.9336 seconds
# 334
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000674.bmp
# Execution Time: 5.9310 seconds
# 335
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000675.bmp
# Execution Time: 5.9389 seconds
# 336
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000676.bmp
# Execution Time: 6.0069 seconds
# 337
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000677.bmp
# Execution Time: 5.9724 seconds
# 338
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000678.bmp
# Execution Time: 5.9246 seconds
# 339
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000679.bmp
# Execution Time: 5.9271 seconds
# 340
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000700.bmp
# Execution Time: 5.9760 seconds
# 341
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000701.bmp
# Execution Time: 5.9295 seconds
# 342
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000702.bmp
# Execution Time: 5.9006 seconds
# 343
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000703.bmp
# Execution Time: 5.9398 seconds
# 344
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000704.bmp
# Execution Time: 5.9410 seconds
# 345
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000705.bmp
# Execution Time: 5.9146 seconds
# 346
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000706.bmp
# Execution Time: 5.9918 seconds
# 347
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000707.bmp
# Execution Time: 5.9293 seconds
# 348
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000708.bmp
# Execution Time: 5.9192 seconds
# 349
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000709.bmp
# Execution Time: 5.9230 seconds
# 350
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000710.bmp
# Execution Time: 5.9393 seconds
# 351
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000711.bmp
# Execution Time: 6.0186 seconds
# 352
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000712.bmp
# Execution Time: 5.9487 seconds
# 353
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000713.bmp
# Execution Time: 5.9438 seconds
# 354
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000714.bmp
# Execution Time: 5.9820 seconds
# 355
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000715.bmp
# Execution Time: 5.9421 seconds
# 356
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000716.bmp
# Execution Time: 5.9208 seconds
# 357
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000717.bmp
# Execution Time: 5.9936 seconds
# 358
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000718.bmp
# Execution Time: 5.9192 seconds
# 359
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000719.bmp
# Execution Time: 5.9004 seconds
# 360
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000740.bmp
# Execution Time: 5.9227 seconds
# 361
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000741.bmp
# Execution Time: 5.9239 seconds
# 362
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000742.bmp
# Execution Time: 5.9211 seconds
# 363
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000743.bmp
# Execution Time: 5.9555 seconds
# 364
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000744.bmp
# Execution Time: 5.9228 seconds
# 365
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000745.bmp
# Execution Time: 5.9176 seconds
# 366
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000746.bmp
# Execution Time: 5.9736 seconds
# 367
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000747.bmp
# Execution Time: 5.9329 seconds
# 368
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000748.bmp
# Execution Time: 5.9960 seconds
# 369
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000749.bmp
# Execution Time: 5.9023 seconds
# 370
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000750.bmp
# Execution Time: 5.9651 seconds
# 371
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000751.bmp
# Execution Time: 5.9301 seconds
# 372
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000752.bmp
# Execution Time: 5.9441 seconds
# 373
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000753.bmp
# Execution Time: 5.9140 seconds
# 374
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000754.bmp
# Execution Time: 5.9845 seconds
# 375
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000755.bmp
# Execution Time: 6.1329 seconds
# 376
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000756.bmp
# Execution Time: 5.9823 seconds
# 377
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000757.bmp
# Execution Time: 5.9096 seconds
# 378
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000758.bmp
# Execution Time: 5.9154 seconds
# 379
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000759.bmp
# Execution Time: 5.9652 seconds
# 380
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000780.bmp
# Execution Time: 5.9491 seconds
# 381
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000781.bmp
# Execution Time: 5.9235 seconds
# 382
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000782.bmp
# Execution Time: 5.9125 seconds
# 383
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000783.bmp
# Execution Time: 5.9244 seconds
# 384
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000784.bmp
# Execution Time: 5.9503 seconds
# 385
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000785.bmp
# Execution Time: 5.9658 seconds
# 386
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000786.bmp
# Execution Time: 5.9515 seconds
# 387
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000787.bmp
# Execution Time: 5.9224 seconds
# 388
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000788.bmp
# Execution Time: 5.9289 seconds
# 389
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000789.bmp
# Execution Time: 5.9309 seconds
# 390
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000790.bmp
# Execution Time: 5.9863 seconds
# 391
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000791.bmp
# Execution Time: 5.9350 seconds
# 392
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000792.bmp
# Execution Time: 5.9444 seconds
# 393
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000793.bmp
# Execution Time: 5.9275 seconds
# 394
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000794.bmp
# Execution Time: 5.9076 seconds
# 395
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000795.bmp
# Execution Time: 5.9127 seconds
# 396
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000796.bmp
# Execution Time: 5.9999 seconds
# 397
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000797.bmp
# Execution Time: 5.9233 seconds
# 398
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000798.bmp
# Execution Time: 5.9286 seconds
# 399
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000799.bmp
# Execution Time: 5.8925 seconds
# 400
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000820.bmp
# Execution Time: 5.9360 seconds
# 401
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000821.bmp
# Execution Time: 6.0598 seconds
# 402
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000822.bmp
# Execution Time: 5.9473 seconds
# 403
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000823.bmp
# Execution Time: 5.9276 seconds
# 404
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000824.bmp
# Execution Time: 5.9271 seconds
# 405
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000825.bmp
# Execution Time: 5.9815 seconds
# 406
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000826.bmp
# Execution Time: 5.9820 seconds
# 407
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000827.bmp
# Execution Time: 5.9564 seconds
# 408
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000828.bmp
# Execution Time: 5.9312 seconds
# 409
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000829.bmp
# Execution Time: 5.9091 seconds
# 410
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000830.bmp
# Execution Time: 5.9749 seconds
# 411
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000831.bmp
# Execution Time: 5.9010 seconds
# 412
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000832.bmp
# Execution Time: 5.9160 seconds
# 413
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000833.bmp
# Execution Time: 5.9400 seconds
# 414
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000834.bmp
# Execution Time: 5.9077 seconds
# 415
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000835.bmp
# Execution Time: 5.9140 seconds
# 416
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000836.bmp
# Execution Time: 5.9047 seconds
# 417
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000837.bmp
# Execution Time: 5.9969 seconds
# 418
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000838.bmp
# Execution Time: 5.9374 seconds
# 419
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000839.bmp
# Execution Time: 5.9183 seconds
# 420
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000860.bmp
# Execution Time: 5.9193 seconds
# 421
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000861.bmp
# Execution Time: 5.9112 seconds
# 422
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000862.bmp
# Execution Time: 5.9464 seconds
# 423
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000863.bmp
# Execution Time: 5.9889 seconds
# 424
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000864.bmp
# Execution Time: 5.9176 seconds
# 425
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000865.bmp
# Execution Time: 5.9794 seconds
# 426
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000866.bmp
# Execution Time: 5.9721 seconds
# 427
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000867.bmp
# Execution Time: 5.9203 seconds
# 428
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000868.bmp
# Execution Time: 5.9331 seconds
# 429
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000869.bmp
# Execution Time: 5.9154 seconds
# 430
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000870.bmp
# Execution Time: 5.9861 seconds
# 431
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000871.bmp
# Execution Time: 5.9285 seconds
# 432
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000872.bmp
# Execution Time: 5.9258 seconds
# 433
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000873.bmp
# Execution Time: 5.8991 seconds
# 434
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000874.bmp
# Execution Time: 5.9233 seconds
# 435
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000875.bmp
# Execution Time: 6.0297 seconds
# 436
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000876.bmp
# Execution Time: 5.9160 seconds
# 437
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000877.bmp
# Execution Time: 5.9356 seconds
# 438
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000878.bmp
# Execution Time: 5.9647 seconds
# 439
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000879.bmp
# Execution Time: 5.9113 seconds
# 440
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000900.bmp
# Execution Time: 5.9200 seconds
# 441
# ...
# 340
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000680.bmp
# Execution Time: 5.9510 seconds
# 341
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000681.bmp
# Execution Time: 5.9188 seconds
# 342
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000682.bmp
# Execution Time: 5.9421 seconds
# 343
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000683.bmp
# Execution Time: 5.9376 seconds
# 344
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000684.bmp
# Execution Time: 5.9627 seconds
# 345
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000685.bmp
# Execution Time: 5.9336 seconds
# 346
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000686.bmp
# Execution Time: 5.9438 seconds
# 347
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000687.bmp
# Execution Time: 5.9229 seconds
# 348
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000688.bmp
# Execution Time: 5.9190 seconds
# 349
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000689.bmp
# Execution Time: 5.9254 seconds
# 350
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000690.bmp
# Execution Time: 5.9999 seconds
# 351
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000691.bmp
# Execution Time: 5.9160 seconds
# 352
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000692.bmp
# Execution Time: 5.9181 seconds
# 353
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000693.bmp
# Execution Time: 5.9212 seconds
# 354
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000694.bmp
# Execution Time: 5.9160 seconds
# 355
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000695.bmp
# Execution Time: 5.9336 seconds
# 356
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000696.bmp
# Execution Time: 5.9433 seconds
# 357
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000697.bmp
# Execution Time: 5.9000 seconds
# 358
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000698.bmp
# Execution Time: 5.9156 seconds
# 359
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000699.bmp
# Execution Time: 5.9203 seconds
# 360
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000720.bmp
# Execution Time: 5.9224 seconds
# 361
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000721.bmp
# Execution Time: 5.9749 seconds
# 362
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000722.bmp
# Execution Time: 5.9127 seconds
# 363
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000723.bmp
# Execution Time: 5.9058 seconds
# 364
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000724.bmp
# Execution Time: 5.9546 seconds
# 365
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000725.bmp
# Execution Time: 5.9046 seconds
# 366
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000726.bmp
# Execution Time: 5.9235 seconds
# 367
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000727.bmp
# Execution Time: 5.9116 seconds
# 368
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000728.bmp
# Execution Time: 5.9273 seconds
# 369
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000729.bmp
# Execution Time: 5.9666 seconds
# 370
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000730.bmp
# Execution Time: 5.9160 seconds
# 371
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000731.bmp
# Execution Time: 5.9122 seconds
# 372
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000732.bmp
# Execution Time: 5.9986 seconds
# 373
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000733.bmp
# Execution Time: 5.9226 seconds
# 374
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000734.bmp
# Execution Time: 5.9501 seconds
# 375
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000735.bmp
# Execution Time: 5.9164 seconds
# 376
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000736.bmp
# Execution Time: 6.0315 seconds
# 377
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000737.bmp
# Execution Time: 5.9271 seconds
# 378
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000738.bmp
# Execution Time: 5.9461 seconds
# 379
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000739.bmp
# Execution Time: 5.9327 seconds
# 380
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000760.bmp
# Execution Time: 5.9081 seconds
# 381
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000761.bmp
# Execution Time: 5.9127 seconds
# 382
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000762.bmp
# Execution Time: 5.9349 seconds
# 383
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000763.bmp
# Execution Time: 6.0367 seconds
# 384
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000764.bmp
# Execution Time: 5.9337 seconds
# 385
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000765.bmp
# Execution Time: 5.9031 seconds
# 386
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000766.bmp
# Execution Time: 5.9179 seconds
# 387
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000767.bmp
# Execution Time: 5.9004 seconds
# 388
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000768.bmp
# Execution Time: 5.9270 seconds
# 389
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000769.bmp
# Execution Time: 5.9086 seconds
# 390
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000770.bmp
# Execution Time: 5.9282 seconds
# 391
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000771.bmp
# Execution Time: 5.9543 seconds
# 392
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000772.bmp
# Execution Time: 5.9126 seconds
# 393
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000773.bmp
# Execution Time: 5.9401 seconds
# 394
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000774.bmp
# Execution Time: 5.9302 seconds
# 395
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000775.bmp
# Execution Time: 5.9150 seconds
# 396
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000776.bmp
# Execution Time: 5.9803 seconds
# 397
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000777.bmp
# Execution Time: 5.9608 seconds
# 398
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000778.bmp
# Execution Time: 5.9411 seconds
# 399
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000779.bmp
# Execution Time: 5.9146 seconds
# 400
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000800.bmp
# Execution Time: 5.9399 seconds
# 401
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000801.bmp
# Execution Time: 5.9015 seconds
# 402
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000802.bmp
# Execution Time: 5.9336 seconds
# 403
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000803.bmp
# Execution Time: 5.9318 seconds
# 404
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000804.bmp
# Execution Time: 5.9254 seconds
# 405
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000805.bmp
# Execution Time: 5.8941 seconds
# 406
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000806.bmp
# Execution Time: 5.9119 seconds
# 407
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000807.bmp
# Execution Time: 5.9278 seconds
# 408
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000808.bmp
# Execution Time: 5.9145 seconds
# 409
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000809.bmp
# Execution Time: 5.9152 seconds
# 410
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000810.bmp
# Execution Time: 6.0007 seconds
# 411
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000811.bmp
# Execution Time: 5.9461 seconds
# 412
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000812.bmp
# Execution Time: 5.8960 seconds
# 413
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000813.bmp
# Execution Time: 5.9171 seconds
# 414
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000814.bmp
# Execution Time: 5.9290 seconds
# 415
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000815.bmp
# Execution Time: 5.9460 seconds
# 416
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000816.bmp
# Execution Time: 5.9114 seconds
# 417
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000817.bmp
# Execution Time: 5.9443 seconds
# 418
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000818.bmp
# Execution Time: 5.9170 seconds
# 419
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000819.bmp
# Execution Time: 5.9153 seconds
# 420
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000840.bmp
# Execution Time: 5.9478 seconds
# 421
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000841.bmp
# Execution Time: 5.9268 seconds
# 422
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000842.bmp
# Execution Time: 5.9890 seconds
# 423
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000843.bmp
# Execution Time: 5.9619 seconds
# 424
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000844.bmp
# Execution Time: 5.9458 seconds
# 425
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000845.bmp
# Execution Time: 5.9966 seconds
# 426
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000846.bmp
# Execution Time: 5.9579 seconds
# 427
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000847.bmp
# Execution Time: 5.9151 seconds
# 428
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000848.bmp
# Execution Time: 5.9140 seconds
# 429
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000849.bmp
# Execution Time: 5.8976 seconds
# 430
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000850.bmp
# Execution Time: 5.9236 seconds
# 431
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000851.bmp
# Execution Time: 5.9401 seconds
# 432
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000852.bmp
# Execution Time: 5.9579 seconds
# 433
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000853.bmp
# Execution Time: 5.9455 seconds
# 434
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000854.bmp
# Execution Time: 5.9784 seconds
# 435
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000855.bmp
# Execution Time: 5.9109 seconds
# 436
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000856.bmp
# Execution Time: 5.9313 seconds
# 437
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000857.bmp
# Execution Time: 5.9193 seconds
# 438
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000858.bmp
# Execution Time: 5.9201 seconds
# 439
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000859.bmp
# Execution Time: 5.9175 seconds
# 440
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000880.bmp
# Execution Time: 5.9086 seconds
# 441
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000881.bmp
# Execution Time: 5.9064 seconds
# 442
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000882.bmp
# Execution Time: 5.9504 seconds
# 443
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000883.bmp
# Execution Time: 6.0162 seconds
# 444
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000884.bmp
# Execution Time: 5.9343 seconds
# 445
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000885.bmp
# Execution Time: 5.9717 seconds
# 446
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000886.bmp
# Execution Time: 5.9397 seconds
# 447
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000887.bmp
# Execution Time: 5.9376 seconds
# 448
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000888.bmp
# Execution Time: 5.9091 seconds
# 449
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000889.bmp
# Execution Time: 5.9258 seconds
# 450
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000890.bmp
# Execution Time: 5.9617 seconds
# 451
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000891.bmp
# Execution Time: 5.9599 seconds
# 452
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000892.bmp
# Execution Time: 5.9184 seconds
# 453
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000893.bmp
# Execution Time: 5.9247 seconds
# 454
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000894.bmp
# Execution Time: 5.9270 seconds
# 455
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000895.bmp
# Execution Time: 6.0009 seconds
# 456
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000896.bmp
# Execution Time: 5.9299 seconds
# 457
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000897.bmp
# Execution Time: 5.9191 seconds
# 458
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000898.bmp
# Execution Time: 5.9169 seconds
# 459
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000899.bmp
# Execution Time: 5.9337 seconds
# 460
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000920.bmp
# Execution Time: 5.9471 seconds
# 461
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000921.bmp
# Execution Time: 5.9324 seconds
# 462
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000922.bmp
# Execution Time: 5.9176 seconds
# 463
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000923.bmp
# Execution Time: 5.9666 seconds
# 464
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000924.bmp
# Execution Time: 5.9418 seconds
# 465
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000925.bmp
# Execution Time: 5.9056 seconds
# 466
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000926.bmp
# Execution Time: 5.9266 seconds
# 467
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000927.bmp
# Execution Time: 6.0036 seconds
# 468
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000928.bmp
# Execution Time: 5.9436 seconds
# 469
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000929.bmp
# Execution Time: 5.9391 seconds
# 470
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000930.bmp
# Execution Time: 5.9128 seconds
# 471
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000931.bmp
# Execution Time: 5.9232 seconds
# 472
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000932.bmp
# Execution Time: 5.9433 seconds
# 473
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000933.bmp
# Execution Time: 5.9441 seconds
# 474
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000934.bmp
# Execution Time: 5.9249 seconds
# 475
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000935.bmp
# Execution Time: 5.9465 seconds
# 476
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000936.bmp
# Execution Time: 5.9376 seconds
# 477
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000937.bmp
# Execution Time: 5.9349 seconds
# 478
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000938.bmp
# Execution Time: 5.9292 seconds
# 479
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00011r\images/000939.bmp
# Execution Time: 5.9752 seconds
# 480
# predictions = 444
# accuracy svm= 92.5
# c:\Users\gbmhi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# predictions = 459
# accuracy nb = 95.625
# predictions = 452
# accuracy lr = 94.16666666666667
# predictions = 466
# accuracy knn = 97.08333333333333

# %%
# Outex_10 = os.path.join(Dataset_dir, "Outex-TC-00010")
# Outex_10
# Out:
# 'D:\\Thesis\\CodeTest\\python\\Train\\Dataset\\Outex-TC-00010'

# %%
# make_train(Outex_10)
# Out:
# Training steps:
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000020.bmp
# Execution Time: 8.5468 seconds
# 1
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000021.bmp
# Execution Time: 7.1161 seconds
# 2
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000022.bmp
# Execution Time: 6.7292 seconds
# 3
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000023.bmp
# Execution Time: 6.6883 seconds
# 4
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000024.bmp
# Execution Time: 6.7373 seconds
# 5
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000025.bmp
# Execution Time: 6.6811 seconds
# 6
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000026.bmp
# Execution Time: 6.6033 seconds
# 7
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000027.bmp
# Execution Time: 6.5628 seconds
# 8
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000028.bmp
# Execution Time: 6.7293 seconds
# 9
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000029.bmp
# Execution Time: 6.8040 seconds
# 10
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000030.bmp
# Execution Time: 6.5080 seconds
# 11
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000031.bmp
# Execution Time: 6.4684 seconds
# 12
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000032.bmp
# Execution Time: 6.5560 seconds
# 13
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000033.bmp
# Execution Time: 6.8205 seconds
# 14
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000034.bmp
# Execution Time: 6.8662 seconds
# 15
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000035.bmp
# Execution Time: 6.6798 seconds
# 16
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000036.bmp
# Execution Time: 6.1556 seconds
# 17
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000037.bmp
# Execution Time: 6.0693 seconds
# 18
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000038.bmp
# Execution Time: 6.2615 seconds
# 19
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000039.bmp
# Execution Time: 6.8736 seconds
# 20
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000040.bmp
# Execution Time: 6.4630 seconds
# 21
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000041.bmp
# Execution Time: 6.2502 seconds
# 22
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000042.bmp
# Execution Time: 6.3859 seconds
# 23
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000043.bmp
# Execution Time: 6.2808 seconds
# 24
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000044.bmp
# Execution Time: 6.3065 seconds
# 25
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000045.bmp
# Execution Time: 6.7736 seconds
# 26
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000046.bmp
# Execution Time: 6.4810 seconds
# 27
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000047.bmp
# Execution Time: 6.0703 seconds
# 28
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000048.bmp
# Execution Time: 6.6145 seconds
# 29
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000049.bmp
# Execution Time: 7.6077 seconds
# 30
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000050.bmp
# Execution Time: 8.2493 seconds
# 31
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000051.bmp
# Execution Time: 6.4433 seconds
# 32
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000052.bmp
# Execution Time: 6.2500 seconds
# 33
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000053.bmp
# Execution Time: 6.1852 seconds
# 34
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000054.bmp
# Execution Time: 6.1779 seconds
# 35
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000055.bmp
# Execution Time: 6.1301 seconds
# 36
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000056.bmp
# Execution Time: 6.4891 seconds
# 37
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000057.bmp
# Execution Time: 6.1085 seconds
# 38
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000058.bmp
# Execution Time: 6.0618 seconds
# 39
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000059.bmp
# Execution Time: 6.6435 seconds
# 40
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000060.bmp
# Execution Time: 6.1526 seconds
# 41
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000061.bmp
# Execution Time: 6.0665 seconds
# 42
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000062.bmp
# Execution Time: 6.7087 seconds
# 43
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000063.bmp
# Execution Time: 6.2184 seconds
# 44
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000064.bmp
# Execution Time: 6.1268 seconds
# 45
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000065.bmp
# Execution Time: 6.2651 seconds
# 46
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000066.bmp
# Execution Time: 6.2513 seconds
# 47
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000067.bmp
# Execution Time: 6.2423 seconds
# 48
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000068.bmp
# Execution Time: 6.2148 seconds
# 49
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000069.bmp
# Execution Time: 6.1320 seconds
# 50
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000070.bmp
# Execution Time: 6.3109 seconds
# 51
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000071.bmp
# Execution Time: 6.7284 seconds
# 52
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000072.bmp
# Execution Time: 6.1191 seconds
# 53
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000073.bmp
# Execution Time: 6.1336 seconds
# 54
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000074.bmp
# Execution Time: 6.1713 seconds
# 55
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000075.bmp
# Execution Time: 6.5316 seconds
# 56
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000076.bmp
# Execution Time: 6.1097 seconds
# 57
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000077.bmp
# Execution Time: 6.1995 seconds
# 58
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000078.bmp
# Execution Time: 6.1095 seconds
# 59
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000079.bmp
# Execution Time: 6.2483 seconds
# 60
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000080.bmp
# Execution Time: 6.2106 seconds
# 61
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000081.bmp
# Execution Time: 6.9789 seconds
# 62
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000082.bmp
# Execution Time: 7.9515 seconds
# 63
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000083.bmp
# Execution Time: 7.7184 seconds
# 64
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000084.bmp
# Execution Time: 6.2496 seconds
# 65
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000085.bmp
# Execution Time: 8.2531 seconds
# 66
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000086.bmp
# Execution Time: 7.8065 seconds
# 67
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000087.bmp
# Execution Time: 7.2196 seconds
# 68
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000088.bmp
# Execution Time: 6.2376 seconds
# 69
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000089.bmp
# Execution Time: 6.3406 seconds
# 70
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000090.bmp
# Execution Time: 6.6107 seconds
# 71
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000091.bmp
# Execution Time: 6.1448 seconds
# 72
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000092.bmp
# Execution Time: 5.9351 seconds
# 73
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000093.bmp
# Execution Time: 7.4698 seconds
# 74
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000094.bmp
# Execution Time: 7.0408 seconds
# 75
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000095.bmp
# Execution Time: 6.7860 seconds
# 76
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000096.bmp
# Execution Time: 6.7842 seconds
# 77
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000097.bmp
# Execution Time: 6.9829 seconds
# 78
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000098.bmp
# Execution Time: 6.9117 seconds
# 79
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000099.bmp
# Execution Time: 6.7321 seconds
# 80
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000100.bmp
# Execution Time: 6.8164 seconds
# 81
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000101.bmp
# Execution Time: 6.8270 seconds
# 82
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000102.bmp
# Execution Time: 6.6348 seconds
# 83
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000103.bmp
# Execution Time: 6.7831 seconds
# 84
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000104.bmp
# Execution Time: 6.6331 seconds
# 85
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000105.bmp
# Execution Time: 6.7728 seconds
# 86
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000106.bmp
# Execution Time: 6.7842 seconds
# 87
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000107.bmp
# Execution Time: 6.6185 seconds
# 88
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000108.bmp
# Execution Time: 6.7269 seconds
# 89
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000109.bmp
# Execution Time: 6.7970 seconds
# 90
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000110.bmp
# Execution Time: 6.7929 seconds
# 91
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000111.bmp
# Execution Time: 6.8297 seconds
# 92
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000112.bmp
# Execution Time: 6.6734 seconds
# 93
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000113.bmp
# Execution Time: 6.7817 seconds
# 94
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000114.bmp
# Execution Time: 6.7819 seconds
# 95
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000115.bmp
# Execution Time: 6.6863 seconds
# 96
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000116.bmp
# Execution Time: 6.6919 seconds
# 97
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000117.bmp
# Execution Time: 6.7270 seconds
# 98
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000118.bmp
# Execution Time: 6.7326 seconds
# 99
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000119.bmp
# Execution Time: 7.4005 seconds
# 100
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000120.bmp
# Execution Time: 6.9981 seconds
# 101
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000121.bmp
# Execution Time: 6.8100 seconds
# 102
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000122.bmp
# Execution Time: 6.6869 seconds
# 103
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000123.bmp
# Execution Time: 6.7614 seconds
# 104
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000124.bmp
# Execution Time: 6.7664 seconds
# 105
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000125.bmp
# Execution Time: 6.6734 seconds
# 106
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000126.bmp
# Execution Time: 6.7283 seconds
# 107
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000127.bmp
# Execution Time: 6.7105 seconds
# 108
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000128.bmp
# Execution Time: 6.7418 seconds
# 109
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000129.bmp
# Execution Time: 6.8628 seconds
# 110
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000130.bmp
# Execution Time: 6.7719 seconds
# 111
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000131.bmp
# Execution Time: 6.7063 seconds
# 112
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000132.bmp
# Execution Time: 6.7260 seconds
# 113
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000133.bmp
# Execution Time: 6.7915 seconds
# 114
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000134.bmp
# Execution Time: 6.7719 seconds
# 115
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000135.bmp
# Execution Time: 6.7028 seconds
# 116
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000136.bmp
# Execution Time: 6.7179 seconds
# 117
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000137.bmp
# Execution Time: 6.7593 seconds
# 118
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000138.bmp
# Execution Time: 6.6637 seconds
# 119
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000139.bmp
# Execution Time: 6.8883 seconds
# 120
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000140.bmp
# Execution Time: 6.7367 seconds
# 121
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000141.bmp
# Execution Time: 6.8435 seconds
# 122
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000142.bmp
# Execution Time: 6.7185 seconds
# 123
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000143.bmp
# Execution Time: 6.6908 seconds
# 124
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000144.bmp
# Execution Time: 6.7166 seconds
# 125
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000145.bmp
# Execution Time: 6.7282 seconds
# 126
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000146.bmp
# Execution Time: 6.7995 seconds
# 127
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000147.bmp
# Execution Time: 6.6716 seconds
# 128
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000148.bmp
# Execution Time: 6.7536 seconds
# 129
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000149.bmp
# Execution Time: 6.6889 seconds
# 130
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000150.bmp
# Execution Time: 6.9249 seconds
# 131
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000151.bmp
# Execution Time: 6.6981 seconds
# 132
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000152.bmp
# Execution Time: 6.6423 seconds
# 133
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000153.bmp
# Execution Time: 6.9375 seconds
# 134
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000154.bmp
# Execution Time: 6.7944 seconds
# 135
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000155.bmp
# Execution Time: 6.8228 seconds
# 136
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000156.bmp
# Execution Time: 6.7791 seconds
# 137
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000157.bmp
# Execution Time: 6.7162 seconds
# 138
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000158.bmp
# Execution Time: 6.8028 seconds
# 139
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000159.bmp
# Execution Time: 6.8125 seconds
# 140
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000160.bmp
# Execution Time: 6.9548 seconds
# 141
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000161.bmp
# Execution Time: 7.1109 seconds
# 142
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000162.bmp
# Execution Time: 6.7681 seconds
# 143
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000163.bmp
# Execution Time: 6.6919 seconds
# 144
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000164.bmp
# Execution Time: 6.6902 seconds
# 145
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000165.bmp
# Execution Time: 6.6748 seconds
# 146
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000166.bmp
# Execution Time: 6.7892 seconds
# 147
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000167.bmp
# Execution Time: 6.7220 seconds
# 148
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000168.bmp
# Execution Time: 6.8291 seconds
# 149
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000169.bmp
# Execution Time: 6.7382 seconds
# 150
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000170.bmp
# Execution Time: 6.7893 seconds
# 151
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000171.bmp
# Execution Time: 6.6285 seconds
# 152
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000172.bmp
# Execution Time: 6.7151 seconds
# 153
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000173.bmp
# Execution Time: 6.6340 seconds
# 154
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000174.bmp
# Execution Time: 6.5799 seconds
# 155
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000175.bmp
# Execution Time: 6.6317 seconds
# 156
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000176.bmp
# Execution Time: 6.8280 seconds
# 157
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000177.bmp
# Execution Time: 6.7356 seconds
# 158
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000178.bmp
# Execution Time: 6.6307 seconds
# 159
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000179.bmp
# Execution Time: 6.6561 seconds
# 160
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000200.bmp
# Execution Time: 6.6337 seconds
# 161
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000201.bmp
# Execution Time: 6.7596 seconds
# 162
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000202.bmp
# Execution Time: 6.6569 seconds
# 163
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000203.bmp
# Execution Time: 6.7015 seconds
# 164
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000204.bmp
# Execution Time: 6.6368 seconds
# 165
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000205.bmp
# Execution Time: 6.7048 seconds
# 166
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000206.bmp
# Execution Time: 6.6596 seconds
# 167
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000207.bmp
# Execution Time: 6.6893 seconds
# 168
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000208.bmp
# Execution Time: 6.7489 seconds
# 169
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000209.bmp
# Execution Time: 6.6049 seconds
# 170
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000210.bmp
# Execution Time: 6.7734 seconds
# 171
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000211.bmp
# Execution Time: 6.7565 seconds
# 172
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000212.bmp
# Execution Time: 6.5912 seconds
# 173
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000213.bmp
# Execution Time: 6.5740 seconds
# 174
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000214.bmp
# Execution Time: 6.6271 seconds
# 175
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000215.bmp
# Execution Time: 6.8950 seconds
# 176
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000216.bmp
# Execution Time: 6.7780 seconds
# 177
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000217.bmp
# Execution Time: 6.7929 seconds
# 178
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000218.bmp
# Execution Time: 6.8539 seconds
# 179
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000219.bmp
# Execution Time: 6.9942 seconds
# 180
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000220.bmp
# Execution Time: 6.7910 seconds
# 181
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000221.bmp
# Execution Time: 6.6885 seconds
# 182
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000222.bmp
# Execution Time: 6.6699 seconds
# 183
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000223.bmp
# Execution Time: 6.6304 seconds
# 184
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000224.bmp
# Execution Time: 6.6593 seconds
# 185
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000225.bmp
# Execution Time: 6.7301 seconds
# 186
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000226.bmp
# Execution Time: 6.8038 seconds
# 187
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000227.bmp
# Execution Time: 6.6823 seconds
# 188
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000228.bmp
# Execution Time: 6.8182 seconds
# 189
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000229.bmp
# Execution Time: 6.8350 seconds
# 190
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000230.bmp
# Execution Time: 6.6881 seconds
# 191
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000231.bmp
# Execution Time: 6.7247 seconds
# 192
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000232.bmp
# Execution Time: 6.7500 seconds
# 193
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000233.bmp
# Execution Time: 6.6656 seconds
# 194
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000234.bmp
# Execution Time: 6.7049 seconds
# 195
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000235.bmp
# Execution Time: 6.6508 seconds
# 196
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000236.bmp
# Execution Time: 6.6718 seconds
# 197
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000237.bmp
# Execution Time: 6.6695 seconds
# 198
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000238.bmp
# Execution Time: 6.6815 seconds
# 199
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000239.bmp
# Execution Time: 6.6542 seconds
# 200
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000240.bmp
# Execution Time: 6.6349 seconds
# 201
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000241.bmp
# Execution Time: 6.7332 seconds
# 202
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000242.bmp
# Execution Time: 6.7982 seconds
# 203
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000243.bmp
# Execution Time: 6.6850 seconds
# 204
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000244.bmp
# Execution Time: 6.6707 seconds
# 205
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000245.bmp
# Execution Time: 6.6847 seconds
# 206
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000246.bmp
# Execution Time: 6.6707 seconds
# 207
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000247.bmp
# Execution Time: 6.6470 seconds
# 208
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000248.bmp
# Execution Time: 6.6644 seconds
# 209
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000249.bmp
# Execution Time: 6.9023 seconds
# 210
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000250.bmp
# Execution Time: 6.8386 seconds
# 211
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000251.bmp
# Execution Time: 6.6066 seconds
# 212
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000252.bmp
# Execution Time: 6.6320 seconds
# 213
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000253.bmp
# Execution Time: 6.6477 seconds
# 214
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000254.bmp
# Execution Time: 6.8943 seconds
# 215
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000255.bmp
# Execution Time: 6.6588 seconds
# 216
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000256.bmp
# Execution Time: 6.6431 seconds
# 217
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000257.bmp
# Execution Time: 6.7594 seconds
# 218
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000258.bmp
# Execution Time: 6.6464 seconds
# 219
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000259.bmp
# Execution Time: 6.8444 seconds
# 220
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000260.bmp
# Execution Time: 6.6482 seconds
# 221
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000261.bmp
# Execution Time: 6.6394 seconds
# 222
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000262.bmp
# Execution Time: 6.8482 seconds
# 223
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000263.bmp
# Execution Time: 6.6253 seconds
# 224
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000264.bmp
# Execution Time: 6.7721 seconds
# 225
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000265.bmp
# Execution Time: 6.7567 seconds
# 226
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000266.bmp
# Execution Time: 6.7115 seconds
# 227
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000267.bmp
# Execution Time: 6.8436 seconds
# 228
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000268.bmp
# Execution Time: 6.6910 seconds
# 229
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000269.bmp
# Execution Time: 6.7565 seconds
# 230
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000270.bmp
# Execution Time: 6.6852 seconds
# 231
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000271.bmp
# Execution Time: 6.6451 seconds
# 232
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000272.bmp
# Execution Time: 6.9345 seconds
# 233
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000273.bmp
# Execution Time: 6.7398 seconds
# 234
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000274.bmp
# Execution Time: 6.8163 seconds
# 235
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000275.bmp
# Execution Time: 6.6860 seconds
# 236
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000276.bmp
# Execution Time: 6.8506 seconds
# 237
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000277.bmp
# Execution Time: 6.7424 seconds
# 238
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000278.bmp
# Execution Time: 6.7153 seconds
# 239
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000279.bmp
# Execution Time: 6.9352 seconds
# 240
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000280.bmp
# Execution Time: 6.7187 seconds
# 241
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000281.bmp
# Execution Time: 6.6845 seconds
# 242
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000282.bmp
# Execution Time: 6.6551 seconds
# 243
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000283.bmp
# Execution Time: 6.6527 seconds
# 244
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000284.bmp
# Execution Time: 6.7211 seconds
# 245
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000285.bmp
# Execution Time: 6.8327 seconds
# 246
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000286.bmp
# Execution Time: 6.7086 seconds
# 247
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000287.bmp
# Execution Time: 6.6714 seconds
# 248
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000288.bmp
# Execution Time: 6.6742 seconds
# 249
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000289.bmp
# Execution Time: 6.6939 seconds
# 250
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000290.bmp
# Execution Time: 6.9643 seconds
# 251
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000291.bmp
# Execution Time: 6.7578 seconds
# 252
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000292.bmp
# Execution Time: 6.7953 seconds
# 253
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000293.bmp
# Execution Time: 6.6619 seconds
# 254
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000294.bmp
# Execution Time: 6.7197 seconds
# 255
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000295.bmp
# Execution Time: 6.6814 seconds
# 256
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000296.bmp
# Execution Time: 6.6541 seconds
# 257
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000297.bmp
# Execution Time: 6.6029 seconds
# 258
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000298.bmp
# Execution Time: 6.6512 seconds
# 259
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000299.bmp
# Execution Time: 6.7035 seconds
# 260
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000300.bmp
# Execution Time: 6.7936 seconds
# 261
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000301.bmp
# Execution Time: 6.7574 seconds
# 262
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000302.bmp
# Execution Time: 6.6509 seconds
# 263
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000303.bmp
# Execution Time: 6.7830 seconds
# 264
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000304.bmp
# Execution Time: 6.7404 seconds
# 265
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000305.bmp
# Execution Time: 6.6967 seconds
# 266
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000306.bmp
# Execution Time: 6.8204 seconds
# 267
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000307.bmp
# Execution Time: 6.6387 seconds
# 268
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000308.bmp
# Execution Time: 6.7308 seconds
# 269
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000309.bmp
# Execution Time: 6.7922 seconds
# 270
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000310.bmp
# Execution Time: 6.6004 seconds
# 271
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000311.bmp
# Execution Time: 6.8076 seconds
# 272
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000312.bmp
# Execution Time: 6.8033 seconds
# 273
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000313.bmp
# Execution Time: 6.9748 seconds
# 274
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000314.bmp
# Execution Time: 6.6936 seconds
# 275
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000315.bmp
# Execution Time: 6.8932 seconds
# 276
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000316.bmp
# Execution Time: 6.6360 seconds
# 277
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000317.bmp
# Execution Time: 6.7635 seconds
# 278
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000318.bmp
# Execution Time: 6.6878 seconds
# 279
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000319.bmp
# Execution Time: 6.6426 seconds
# 280
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000320.bmp
# Execution Time: 6.6783 seconds
# 281
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000321.bmp
# Execution Time: 6.7323 seconds
# 282
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000322.bmp
# Execution Time: 6.7703 seconds
# 283
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000323.bmp
# Execution Time: 6.6163 seconds
# 284
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000324.bmp
# Execution Time: 6.7276 seconds
# 285
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000325.bmp
# Execution Time: 6.6703 seconds
# 286
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000326.bmp
# Execution Time: 6.6711 seconds
# 287
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000327.bmp
# Execution Time: 6.6343 seconds
# 288
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000328.bmp
# Execution Time: 6.6708 seconds
# 289
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000329.bmp
# Execution Time: 6.6615 seconds
# 290
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000330.bmp
# Execution Time: 6.8223 seconds
# 291
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000331.bmp
# Execution Time: 6.7638 seconds
# 292
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000332.bmp
# Execution Time: 6.6159 seconds
# 293
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000333.bmp
# Execution Time: 6.5862 seconds
# 294
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000334.bmp
# Execution Time: 6.6063 seconds
# 295
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000335.bmp
# Execution Time: 6.6075 seconds
# 296
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000336.bmp
# Execution Time: 6.7379 seconds
# 297
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000337.bmp
# Execution Time: 6.6671 seconds
# 298
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000338.bmp
# Execution Time: 6.7833 seconds
# 299
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000339.bmp
# Execution Time: 6.8422 seconds
# 300
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000340.bmp
# Execution Time: 6.6305 seconds
# 301
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000341.bmp
# Execution Time: 6.5909 seconds
# 302
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000342.bmp
# Execution Time: 6.6765 seconds
# 303
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000343.bmp
# Execution Time: 6.6621 seconds
# 304
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000344.bmp
# Execution Time: 6.6630 seconds
# 305
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000345.bmp
# Execution Time: 6.5918 seconds
# 306
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000346.bmp
# Execution Time: 6.7202 seconds
# 307
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000347.bmp
# Execution Time: 6.8128 seconds
# 308
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000348.bmp
# Execution Time: 6.7201 seconds
# 309
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000349.bmp
# Execution Time: 6.7716 seconds
# 310
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000350.bmp
# Execution Time: 6.6708 seconds
# 311
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000351.bmp
# Execution Time: 6.6462 seconds
# 312
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000352.bmp
# Execution Time: 6.6441 seconds
# 313
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000353.bmp
# Execution Time: 6.7732 seconds
# 314
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000354.bmp
# Execution Time: 6.7610 seconds
# 315
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000355.bmp
# Execution Time: 6.6268 seconds
# 316
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000356.bmp
# Execution Time: 6.7493 seconds
# 317
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000357.bmp
# Execution Time: 6.2666 seconds
# 318
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000358.bmp
# Execution Time: 6.2983 seconds
# 319
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000359.bmp
# Execution Time: 6.5825 seconds
# 320
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000380.bmp
# Execution Time: 6.6233 seconds
# 321
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000381.bmp
# Execution Time: 6.6584 seconds
# 322
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000382.bmp
# Execution Time: 6.5089 seconds
# 323
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000383.bmp
# Execution Time: 6.3161 seconds
# 324
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000384.bmp
# Execution Time: 6.5747 seconds
# 325
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000385.bmp
# Execution Time: 6.6970 seconds
# 326
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000386.bmp
# Execution Time: 6.7139 seconds
# 327
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000387.bmp
# Execution Time: 6.7883 seconds
# 328
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000388.bmp
# Execution Time: 6.5329 seconds
# 329
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000389.bmp
# Execution Time: 6.5306 seconds
# 330
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000390.bmp
# Execution Time: 6.5915 seconds
# 331
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000391.bmp
# Execution Time: 6.5332 seconds
# 332
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000392.bmp
# Execution Time: 6.4393 seconds
# 333
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000393.bmp
# Execution Time: 6.4326 seconds
# 334
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000394.bmp
# Execution Time: 6.7765 seconds
# 335
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000395.bmp
# Execution Time: 6.4480 seconds
# 336
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000396.bmp
# Execution Time: 6.4201 seconds
# 337
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000397.bmp
# Execution Time: 6.6806 seconds
# 338
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000398.bmp
# Execution Time: 6.3966 seconds
# 339
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000399.bmp
# Execution Time: 6.6163 seconds
# 340
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000400.bmp
# Execution Time: 6.4868 seconds
# 341
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000401.bmp
# Execution Time: 6.6082 seconds
# 342
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000402.bmp
# Execution Time: 6.4997 seconds
# 343
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000403.bmp
# Execution Time: 6.4063 seconds
# 344
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000404.bmp
# Execution Time: 6.3863 seconds
# 345
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000405.bmp
# Execution Time: 6.7427 seconds
# 346
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000406.bmp
# Execution Time: 6.7736 seconds
# 347
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000407.bmp
# Execution Time: 7.0347 seconds
# 348
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000408.bmp
# Execution Time: 6.6431 seconds
# 349
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000409.bmp
# Execution Time: 6.5066 seconds
# 350
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000410.bmp
# Execution Time: 6.6030 seconds
# 351
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000411.bmp
# Execution Time: 6.4415 seconds
# 352
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000412.bmp
# Execution Time: 6.6982 seconds
# 353
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000413.bmp
# Execution Time: 6.5922 seconds
# 354
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000414.bmp
# Execution Time: 6.6646 seconds
# 355
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000415.bmp
# Execution Time: 6.5161 seconds
# 356
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000416.bmp
# Execution Time: 6.7750 seconds
# 357
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000417.bmp
# Execution Time: 6.8101 seconds
# 358
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000418.bmp
# Execution Time: 6.7227 seconds
# 359
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000419.bmp
# Execution Time: 6.6180 seconds
# 360
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000420.bmp
# Execution Time: 6.5242 seconds
# 361
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000421.bmp
# Execution Time: 6.3581 seconds
# 362
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000422.bmp
# Execution Time: 6.5776 seconds
# 363
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000423.bmp
# Execution Time: 6.8483 seconds
# 364
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000424.bmp
# Execution Time: 6.5323 seconds
# 365
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000425.bmp
# Execution Time: 6.4998 seconds
# 366
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000426.bmp
# Execution Time: 6.4975 seconds
# 367
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000427.bmp
# Execution Time: 6.6890 seconds
# 368
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000428.bmp
# Execution Time: 6.7001 seconds
# 369
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000429.bmp
# Execution Time: 6.4414 seconds
# 370
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000430.bmp
# Execution Time: 6.6299 seconds
# 371
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000431.bmp
# Execution Time: 6.6406 seconds
# 372
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000432.bmp
# Execution Time: 6.6617 seconds
# 373
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000433.bmp
# Execution Time: 6.6492 seconds
# 374
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000434.bmp
# Execution Time: 6.3628 seconds
# 375
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000435.bmp
# Execution Time: 6.4753 seconds
# 376
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000436.bmp
# Execution Time: 6.4946 seconds
# 377
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000437.bmp
# Execution Time: 6.5514 seconds
# 378
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000438.bmp
# Execution Time: 6.3602 seconds
# 379
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000439.bmp
# Execution Time: 6.3739 seconds
# 380
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000440.bmp
# Execution Time: 6.5185 seconds
# 381
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000441.bmp
# Execution Time: 6.4425 seconds
# 382
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000442.bmp
# Execution Time: 6.5976 seconds
# 383
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000443.bmp
# Execution Time: 6.6890 seconds
# 384
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000444.bmp
# Execution Time: 6.3912 seconds
# 385
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000445.bmp
# Execution Time: 6.4894 seconds
# 386
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000446.bmp
# Execution Time: 6.5720 seconds
# 387
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000447.bmp
# Execution Time: 6.3836 seconds
# 388
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000448.bmp
# Execution Time: 6.4256 seconds
# 389
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000449.bmp
# Execution Time: 6.5266 seconds
# 390
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000450.bmp
# Execution Time: 6.7561 seconds
# 391
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000451.bmp
# Execution Time: 6.8811 seconds
# 392
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000452.bmp
# Execution Time: 6.5616 seconds
# 393
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000453.bmp
# Execution Time: 6.5965 seconds
# 394
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000454.bmp
# Execution Time: 6.5196 seconds
# 395
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000455.bmp
# Execution Time: 6.5348 seconds
# 396
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000456.bmp
# Execution Time: 6.8890 seconds
# 397
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000457.bmp
# Execution Time: 7.0897 seconds
# 398
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000458.bmp
# Execution Time: 7.0363 seconds
# 399
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000459.bmp
# Execution Time: 6.8692 seconds
# 400
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000460.bmp
# Execution Time: 6.8744 seconds
# 401
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000461.bmp
# Execution Time: 6.9537 seconds
# 402
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000462.bmp
# Execution Time: 6.8827 seconds
# 403
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000463.bmp
# Execution Time: 6.8548 seconds
# 404
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000464.bmp
# Execution Time: 6.6840 seconds
# 405
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000465.bmp
# Execution Time: 6.7394 seconds
# 406
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000466.bmp
# Execution Time: 6.6143 seconds
# 407
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000467.bmp
# Execution Time: 6.6421 seconds
# 408
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000468.bmp
# Execution Time: 6.5771 seconds
# 409
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000469.bmp
# Execution Time: 6.6770 seconds
# 410
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000470.bmp
# Execution Time: 6.4413 seconds
# 411
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000471.bmp
# Execution Time: 6.6735 seconds
# 412
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000472.bmp
# Execution Time: 6.7243 seconds
# 413
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000473.bmp
# Execution Time: 6.5432 seconds
# 414
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000474.bmp
# Execution Time: 6.6443 seconds
# 415
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000475.bmp
# Execution Time: 6.5828 seconds
# 416
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000476.bmp
# Execution Time: 6.6173 seconds
# 417
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000477.bmp
# Execution Time: 6.5568 seconds
# 418
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000478.bmp
# Execution Time: 6.8457 seconds
# 419
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000479.bmp
# Execution Time: 6.6385 seconds
# 420
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000480.bmp
# Execution Time: 6.7428 seconds
# 421
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000481.bmp
# Execution Time: 6.6811 seconds
# 422
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000482.bmp
# Execution Time: 6.4234 seconds
# 423
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000483.bmp
# Execution Time: 6.3435 seconds
# 424
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000484.bmp
# Execution Time: 6.6402 seconds
# 425
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000485.bmp
# Execution Time: 6.5266 seconds
# 426
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000486.bmp
# Execution Time: 6.6901 seconds
# 427
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000487.bmp
# Execution Time: 6.5487 seconds
# 428
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000488.bmp
# Execution Time: 6.6306 seconds
# 429
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000489.bmp
# Execution Time: 6.5032 seconds
# 430
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000490.bmp
# Execution Time: 6.5396 seconds
# 431
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000491.bmp
# Execution Time: 6.4448 seconds
# 432
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000492.bmp
# Execution Time: 6.3206 seconds
# 433
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000493.bmp
# Execution Time: 6.2880 seconds
# 434
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000494.bmp
# Execution Time: 6.4020 seconds
# 435
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000495.bmp
# Execution Time: 6.4554 seconds
# 436
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000496.bmp
# Execution Time: 6.5035 seconds
# 437
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000497.bmp
# Execution Time: 6.4670 seconds
# 438
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000498.bmp
# Execution Time: 6.4466 seconds
# 439
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000499.bmp
# Execution Time: 6.6165 seconds
# 440
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000500.bmp
# Execution Time: 6.3602 seconds
# 441
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000501.bmp
# Execution Time: 6.6639 seconds
# 442
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000502.bmp
# Execution Time: 6.6147 seconds
# 443
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000503.bmp
# Execution Time: 6.6157 seconds
# 444
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/000504.bmp
# Execution Time: 6.6819 seconds
# 445
# ...
# Execution Time: 5.7716 seconds
# 339
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/002899.bmp
# Execution Time: 5.7780 seconds
# 340
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003060.bmp
# Execution Time: 5.8316 seconds
# 341
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003061.bmp
# Execution Time: 5.7538 seconds
# 342
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003062.bmp
# Execution Time: 5.7879 seconds
# 343
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003063.bmp
# Execution Time: 5.8039 seconds
# 344
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003064.bmp
# Execution Time: 5.8624 seconds
# 345
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003065.bmp
# Execution Time: 5.7687 seconds
# 346
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003066.bmp
# Execution Time: 5.7471 seconds
# 347
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003067.bmp
# Execution Time: 5.7925 seconds
# 348
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003068.bmp
# Execution Time: 5.8128 seconds
# 349
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003069.bmp
# Execution Time: 5.7404 seconds
# 350
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003070.bmp
# Execution Time: 5.7771 seconds
# 351
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003071.bmp
# Execution Time: 5.7611 seconds
# 352
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003072.bmp
# Execution Time: 5.8067 seconds
# 353
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003073.bmp
# Execution Time: 5.8217 seconds
# 354
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003074.bmp
# Execution Time: 5.8087 seconds
# 355
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003075.bmp
# Execution Time: 5.7713 seconds
# 356
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003076.bmp
# Execution Time: 5.8161 seconds
# 357
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003077.bmp
# Execution Time: 5.7672 seconds
# 358
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003078.bmp
# Execution Time: 5.7776 seconds
# 359
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003079.bmp
# Execution Time: 5.7570 seconds
# 360
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003240.bmp
# Execution Time: 5.7999 seconds
# 361
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003241.bmp
# Execution Time: 5.8235 seconds
# 362
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003242.bmp
# Execution Time: 5.7997 seconds
# 363
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003243.bmp
# Execution Time: 5.7784 seconds
# 364
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003244.bmp
# Execution Time: 5.8178 seconds
# 365
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003245.bmp
# Execution Time: 5.7742 seconds
# 366
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003246.bmp
# Execution Time: 5.7506 seconds
# 367
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003247.bmp
# Execution Time: 5.7727 seconds
# 368
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003248.bmp
# Execution Time: 5.8066 seconds
# 369
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003249.bmp
# Execution Time: 5.7535 seconds
# 370
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003250.bmp
# Execution Time: 5.8038 seconds
# 371
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003251.bmp
# Execution Time: 5.8293 seconds
# 372
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003252.bmp
# Execution Time: 5.7771 seconds
# 373
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003253.bmp
# Execution Time: 5.7509 seconds
# 374
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003254.bmp
# Execution Time: 5.7620 seconds
# 375
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003255.bmp
# Execution Time: 5.8022 seconds
# 376
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003256.bmp
# Execution Time: 5.7717 seconds
# 377
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003257.bmp
# Execution Time: 5.7452 seconds
# 378
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003258.bmp
# Execution Time: 5.7646 seconds
# 379
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003259.bmp
# Execution Time: 5.8093 seconds
# 380
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003420.bmp
# Execution Time: 5.8519 seconds
# 381
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003421.bmp
# Execution Time: 5.7808 seconds
# 382
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003422.bmp
# Execution Time: 5.7909 seconds
# 383
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003423.bmp
# Execution Time: 5.7965 seconds
# 384
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003424.bmp
# Execution Time: 5.8821 seconds
# 385
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003425.bmp
# Execution Time: 5.7232 seconds
# 386
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003426.bmp
# Execution Time: 5.8223 seconds
# 387
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003427.bmp
# Execution Time: 5.8424 seconds
# 388
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003428.bmp
# Execution Time: 5.8210 seconds
# 389
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003429.bmp
# Execution Time: 5.7526 seconds
# 390
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003430.bmp
# Execution Time: 5.8353 seconds
# 391
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003431.bmp
# Execution Time: 5.8555 seconds
# 392
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003432.bmp
# Execution Time: 5.7752 seconds
# 393
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003433.bmp
# Execution Time: 5.8272 seconds
# 394
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003434.bmp
# Execution Time: 5.7918 seconds
# 395
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003435.bmp
# Execution Time: 5.8580 seconds
# 396
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003436.bmp
# Execution Time: 5.7755 seconds
# 397
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003437.bmp
# Execution Time: 5.7748 seconds
# 398
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003438.bmp
# Execution Time: 5.7880 seconds
# 399
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003439.bmp
# Execution Time: 5.8183 seconds
# 400
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003600.bmp
# Execution Time: 5.8127 seconds
# 401
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003601.bmp
# Execution Time: 5.7725 seconds
# 402
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003602.bmp
# Execution Time: 5.8256 seconds
# 403
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003603.bmp
# Execution Time: 5.7769 seconds
# 404
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003604.bmp
# Execution Time: 5.7799 seconds
# 405
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003605.bmp
# Execution Time: 5.8503 seconds
# 406
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003606.bmp
# Execution Time: 5.7731 seconds
# 407
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003607.bmp
# Execution Time: 5.7688 seconds
# 408
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003608.bmp
# Execution Time: 5.8153 seconds
# 409
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003609.bmp
# Execution Time: 5.8318 seconds
# 410
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003610.bmp
# Execution Time: 5.7963 seconds
# 411
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003611.bmp
# Execution Time: 5.8089 seconds
# 412
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003612.bmp
# Execution Time: 5.7747 seconds
# 413
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003613.bmp
# Execution Time: 5.7722 seconds
# 414
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003614.bmp
# Execution Time: 5.8038 seconds
# 415
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003615.bmp
# Execution Time: 5.7848 seconds
# 416
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003616.bmp
# Execution Time: 5.8068 seconds
# 417
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003617.bmp
# Execution Time: 5.9835 seconds
# 418
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003618.bmp
# Execution Time: 5.7933 seconds
# 419
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003619.bmp
# Execution Time: 5.8366 seconds
# 420
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003780.bmp
# Execution Time: 5.7704 seconds
# 421
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003781.bmp
# Execution Time: 5.8180 seconds
# 422
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003782.bmp
# Execution Time: 5.7725 seconds
# 423
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003783.bmp
# Execution Time: 5.8263 seconds
# 424
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003784.bmp
# Execution Time: 5.7954 seconds
# 425
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003785.bmp
# Execution Time: 5.8848 seconds
# 426
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003786.bmp
# Execution Time: 5.7901 seconds
# 427
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003787.bmp
# Execution Time: 5.8430 seconds
# 428
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003788.bmp
# Execution Time: 5.7733 seconds
# 429
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003789.bmp
# Execution Time: 5.8352 seconds
# 430
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003790.bmp
# Execution Time: 5.7838 seconds
# 431
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003791.bmp
# Execution Time: 5.7441 seconds
# 432
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003792.bmp
# Execution Time: 5.8102 seconds
# 433
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003793.bmp
# Execution Time: 5.7800 seconds
# 434
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003794.bmp
# Execution Time: 5.8234 seconds
# 435
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003795.bmp
# Execution Time: 5.9171 seconds
# 436
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003796.bmp
# Execution Time: 5.8753 seconds
# 437
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003797.bmp
# Execution Time: 5.8754 seconds
# 438
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003798.bmp
# Execution Time: 5.7714 seconds
# 439
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003799.bmp
# Execution Time: 5.8343 seconds
# 440
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003960.bmp
# Execution Time: 5.7807 seconds
# 441
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003961.bmp
# Execution Time: 5.7969 seconds
# 442
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003962.bmp
# Execution Time: 5.8155 seconds
# 443
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003963.bmp
# Execution Time: 5.8231 seconds
# 444
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003964.bmp
# Execution Time: 5.9076 seconds
# 445
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003965.bmp
# Execution Time: 5.7923 seconds
# 446
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003966.bmp
# Execution Time: 5.8636 seconds
# 447
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003967.bmp
# Execution Time: 5.7677 seconds
# 448
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003968.bmp
# Execution Time: 5.8714 seconds
# 449
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003969.bmp
# Execution Time: 5.7552 seconds
# 450
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003970.bmp
# Execution Time: 5.8214 seconds
# 451
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003971.bmp
# Execution Time: 5.7880 seconds
# 452
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003972.bmp
# Execution Time: 5.7928 seconds
# 453
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003973.bmp
# Execution Time: 5.8311 seconds
# 454
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003974.bmp
# Execution Time: 5.8690 seconds
# 455
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003975.bmp
# Execution Time: 5.7657 seconds
# 456
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003976.bmp
# Execution Time: 5.7976 seconds
# 457
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003977.bmp
# Execution Time: 5.8236 seconds
# 458
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003978.bmp
# Execution Time: 5.8033 seconds
# 459
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/003979.bmp
# Execution Time: 5.7699 seconds
# 460
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/004140.bmp
# Execution Time: 5.8540 seconds
# 461
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/004141.bmp
# Execution Time: 5.7642 seconds
# 462
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/004142.bmp
# Execution Time: 5.9086 seconds
# 463
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/004143.bmp
# Execution Time: 5.7982 seconds
# 464
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/004144.bmp
# Execution Time: 5.7987 seconds
# 465
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/004145.bmp
# Execution Time: 5.8116 seconds
# 466
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/004146.bmp
# Execution Time: 5.7926 seconds
# 467
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/004147.bmp
# Execution Time: 5.7381 seconds
# 468
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/004148.bmp
# Execution Time: 5.8690 seconds
# 469
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/004149.bmp
# Execution Time: 5.8003 seconds
# 470
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/004150.bmp
# Execution Time: 5.8229 seconds
# 471
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/004151.bmp
# Execution Time: 5.7776 seconds
# 472
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/004152.bmp
# Execution Time: 5.8703 seconds
# 473
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/004153.bmp
# Execution Time: 5.7613 seconds
# 474
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/004154.bmp
# Execution Time: 5.8569 seconds
# 475
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/004155.bmp
# Execution Time: 5.7595 seconds
# 476
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/004156.bmp
# Execution Time: 5.8254 seconds
# 477
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/004157.bmp
# Execution Time: 5.8620 seconds
# 478
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/004158.bmp
# Execution Time: 5.8386 seconds
# 479
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00010\images/004159.bmp
# Execution Time: 5.7755 seconds
# 480
# predictions = 479
# accuracy svm= 99.79166666666667
# c:\Users\gbmhi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# predictions = 474
# accuracy nb = 98.75
# predictions = 480
# accuracy lr = 100.0
# predictions = 480
# accuracy knn = 100.0

# %%
Outex_12 = os.path.join(Dataset_dir, "Outex-TC-00012-bmp")
Outex_12
# Out:
# 'D:\\Thesis\\CodeTest\\python\\Train\\Dataset\\Outex-TC-00012-bmp'

# %%
make_train(Outex_12)
# Out:
# Training steps:
# D:\Thesis\CodeTest\python\Train\Dataset\Outex-TC-00012-bmp\images/000480.bmp
